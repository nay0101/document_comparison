# %%
from documentParseJson.split_pdf import split_pdf

split_pdf("./data_sources/pd_product_transparency_and_disclosure_clean.pdf", out_dir="./document_chunks", pages_per_chunk=5)
# Out:
# Saved document_chunks\chunk_0001_to_0005.pdf
# Saved document_chunks\chunk_0006_to_0010.pdf
# Saved document_chunks\chunk_0011_to_0015.pdf
# Saved document_chunks\chunk_0016_to_0020.pdf
# Saved document_chunks\chunk_0021_to_0025.pdf
# Saved document_chunks\chunk_0026_to_0030.pdf
# Saved document_chunks\chunk_0031_to_0035.pdf
# Saved document_chunks\chunk_0036_to_0040.pdf
# Saved document_chunks\chunk_0041_to_0045.pdf
# Saved document_chunks\chunk_0046_to_0050.pdf
# Saved document_chunks\chunk_0051_to_0055.pdf
# Saved document_chunks\chunk_0056_to_0060.pdf
# Saved document_chunks\chunk_0061_to_0065.pdf
# Saved document_chunks\chunk_0066_to_0070.pdf
# Saved document_chunks\chunk_0071_to_0075.pdf
# Saved document_chunks\chunk_0076_to_0080.pdf
# Saved document_chunks\chunk_0081_to_0085.pdf
# Saved document_chunks\chunk_0086_to_0090.pdf
# Saved document_chunks\chunk_0091_to_0095.pdf
# Saved document_chunks\chunk_0096_to_0100.pdf
# Saved document_chunks\chunk_0101_to_0102.pdf

# %%
from documentParseJson.output_schema import Document

Document.model_json_schema()
# Out:
# {'$defs': {'CodeBlock': {'description': 'A fenced code block.',
#    'properties': {'kind': {'const': 'code',
#      'default': 'code',
#      'description': 'Discriminator tag for this block type.',
#      'title': 'Kind',
#      'type': 'string'},
#     'lang': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#      'default': '',
#      'description': "Optional language hint for syntax highlighting (e.g., 'python').",
#      'title': 'Lang'},
#     'code': {'description': 'Raw code contents as monospaced text.',
#      'title': 'Code',
#      'type': 'string'}},
#    'required': ['code'],
#    'title': 'CodeBlock',
#    'type': 'object'},
#   'FigureBlock': {'description': 'A figure or illustration with optional caption/alt text.',
#    'properties': {'kind': {'const': 'figure',
#      'default': 'figure',
#      'description': 'Discriminator tag for this block type.',
#      'title': 'Kind',
#      'type': 'string'},
#     'caption': {'default': '',
#      'description': 'Human-readable caption/legend shown near the figure.',
#      'title': 'Caption',
#      'type': 'string'},
#     'alt': {'default': '',
#      'description': "Alternative text describing the figure's content for accessibility.",
#      'title': 'Alt',
#      'type': 'string'}},
#    'title': 'FigureBlock',
#    'type': 'object'},
#   'FootnoteBlock': {'description': 'A footnote definition mapping a reference marker to text.',
#    'properties': {'kind': {'const': 'footnote',
#      'default': 'footnote',
#      'description': 'Discriminator tag for this block type.',
#      'title': 'Kind',
#      'type': 'string'},
#     'ref': {'description': "The footnote reference/marker (e.g., '1', '†') that appears in the main text.",
#      'title': 'Ref',
#      'type': 'string'},
#     'text': {'description': 'The full footnote text associated with the marker.',
#      'title': 'Text',
#      'type': 'string'}},
#    'required': ['ref', 'text'],
#    'title': 'FootnoteBlock',
#    'type': 'object'},
#   'HeadingBlock': {'description': 'A heading/title line within the document content hierarchy.',
#    'properties': {'kind': {'const': 'heading',
#      'default': 'heading',
#      'description': 'Discriminator tag for this block type.',
#      'title': 'Kind',
#      'type': 'string'},
#     'level': {'description': 'Heading depth where 1 is the top-most level (e.g., H1) and 6 is the deepest (H6).',
#      'maximum': 6,
#      'minimum': 1,
#      'title': 'Level',
#      'type': 'integer'},
#     'text': {'description': 'Plain text content of the heading as it appears on the page.',
#      'title': 'Text',
#      'type': 'string'}},
#    'required': ['level', 'text'],
#    'title': 'HeadingBlock',
#    'type': 'object'},
#   'ListBlock': {'description': 'A list block containing ordered or unordered items.',
#    'properties': {'kind': {'const': 'list',
#      'default': 'list',
#      'description': 'Discriminator tag for this block type.',
#      'title': 'Kind',
#      'type': 'string'},
#     'ordered': {'description': 'True for an ordered list (1., a., i.), False for an unordered list (bullets).',
#      'title': 'Ordered',
#      'type': 'boolean'},
#     'items': {'description': 'Each list item as plain text, in visual order.',
#      'items': {'type': 'string'},
#      'title': 'Items',
#      'type': 'array'}},
#    'required': ['ordered'],
#    'title': 'ListBlock',
#    'type': 'object'},
#   'Page': {'description': 'A single page of the document with optional header/footer and main content blocks.',
#    'properties': {'page_number': {'description': '1-based page index within the document.',
#      'minimum': 1,
#      'title': 'Page Number',
#      'type': 'integer'},
#     'header': {'description': 'Top-of-page region; empty if none.',
#      'title': 'Header',
#      'type': 'string'},
#     'footer': {'description': 'Bottom-of-page region; empty if none.',
#      'title': 'Footer',
#      'type': 'string'},
#     'blocks': {'description': 'Main body content blocks for this page, in reading order, excluding header/footer.',
#      'items': {'anyOf': [{'$ref': '#/$defs/HeadingBlock'},
#        {'$ref': '#/$defs/ParagraphBlock'},
#        {'$ref': '#/$defs/ListBlock'},
#        {'$ref': '#/$defs/TableBlock'},
#        {'$ref': '#/$defs/CodeBlock'},
#        {'$ref': '#/$defs/FigureBlock'},
#        {'$ref': '#/$defs/FootnoteBlock'}]},
#      'title': 'Blocks',
#      'type': 'array'}},
#    'required': ['page_number'],
#    'title': 'Page',
#    'type': 'object'},
#   'ParagraphBlock': {'description': 'A paragraph of running body text.',
#    'properties': {'kind': {'const': 'paragraph',
#      'default': 'paragraph',
#      'description': 'Discriminator tag for this block type.',
#      'title': 'Kind',
#      'type': 'string'},
#     'text': {'description': 'Plain text content of the paragraph, preserving reading order.',
#      'title': 'Text',
#      'type': 'string'}},
#    'required': ['text'],
#    'title': 'ParagraphBlock',
#    'type': 'object'},
#   'TableBlock': {'description': 'A rectangular table represented as rows of cell text.',
#    'properties': {'kind': {'const': 'table',
#      'default': 'table',
#      'description': 'Discriminator tag for this block type.',
#      'title': 'Kind',
#      'type': 'string'},
#     'rows': {'description': '2D array of table cells; each inner list is a row. All rows must have equal length.',
#      'items': {'items': {'type': 'string'}, 'type': 'array'},
#      'title': 'Rows',
#      'type': 'array'}},
#    'title': 'TableBlock',
#    'type': 'object'}},
#  'description': 'The full extracted document, organized by pages.',
#  'properties': {'pages': {'description': 'List of pages in reading order.',
#    'items': {'$ref': '#/$defs/Page'},
#    'minItems': 1,
#    'title': 'Pages',
#    'type': 'array'}},
#  'required': ['pages'],
#  'title': 'Document',
#  'type': 'object'}

# %%
from documentParseJson.output_schema import Document
import json

schema = Document.model_json_schema()
json_format = json.dumps(schema, indent=2)
print(json_format)
# Out:
# {
#   "$defs": {
#     "CodeBlock": {
#       "description": "A fenced code block.",
#       "properties": {
#         "kind": {
#           "const": "code",
#           "default": "code",
#           "description": "Discriminator tag for this block type.",
#           "title": "Kind",
#           "type": "string"
#         },
#         "lang": {
#           "anyOf": [
#             {
#               "type": "string"
#             },
#             {
#               "type": "null"
#             }
#           ],
#           "default": "",
#           "description": "Optional language hint for syntax highlighting (e.g., 'python').",
#           "title": "Lang"
#         },
#         "code": {
#           "description": "Raw code contents as monospaced text.",
#           "title": "Code",
#           "type": "string"
#         }
#       },
#       "required": [
#         "code"
#       ],
#       "title": "CodeBlock",
#       "type": "object"
#     },
#     "FigureBlock": {
#       "description": "A figure or illustration with optional caption/alt text.",
#       "properties": {
#         "kind": {
#           "const": "figure",
#           "default": "figure",
#           "description": "Discriminator tag for this block type.",
#           "title": "Kind",
#           "type": "string"
#         },
#         "caption": {
#           "default": "",
#           "description": "Human-readable caption/legend shown near the figure.",
#           "title": "Caption",
#           "type": "string"
#         },
#         "alt": {
#           "default": "",
#           "description": "Alternative text describing the figure's content for accessibility.",
#           "title": "Alt",
#           "type": "string"
#         }
#       },
#       "title": "FigureBlock",
#       "type": "object"
#     },
#     "FootnoteBlock": {
#       "description": "A footnote definition mapping a reference marker to text.",
#       "properties": {
#         "kind": {
#           "const": "footnote",
#           "default": "footnote",
#           "description": "Discriminator tag for this block type.",
#           "title": "Kind",
#           "type": "string"
#         },
#         "ref": {
#           "description": "The footnote reference/marker (e.g., '1', '\u2020') that appears in the main text.",
#           "title": "Ref",
#           "type": "string"
#         },
#         "text": {
#           "description": "The full footnote text associated with the marker.",
#           "title": "Text",
#           "type": "string"
#         }
#       },
#       "required": [
#         "ref",
#         "text"
#       ],
#       "title": "FootnoteBlock",
#       "type": "object"
#     },
#     "HeadingBlock": {
#       "description": "A heading/title line within the document content hierarchy.",
#       "properties": {
#         "kind": {
#           "const": "heading",
#           "default": "heading",
#           "description": "Discriminator tag for this block type.",
#           "title": "Kind",
#           "type": "string"
#         },
#         "level": {
#           "description": "Heading depth where 1 is the top-most level (e.g., H1) and 6 is the deepest (H6).",
#           "maximum": 6,
#           "minimum": 1,
#           "title": "Level",
#           "type": "integer"
#         },
#         "text": {
#           "description": "Plain text content of the heading as it appears on the page.",
#           "title": "Text",
#           "type": "string"
#         }
#       },
#       "required": [
#         "level",
#         "text"
#       ],
#       "title": "HeadingBlock",
#       "type": "object"
#     },
#     "ListBlock": {
#       "description": "A list block containing ordered or unordered items.",
#       "properties": {
#         "kind": {
#           "const": "list",
#           "default": "list",
#           "description": "Discriminator tag for this block type.",
#           "title": "Kind",
#           "type": "string"
#         },
#         "ordered": {
#           "description": "True for an ordered list (1., a., i.), False for an unordered list (bullets).",
#           "title": "Ordered",
#           "type": "boolean"
#         },
#         "items": {
#           "description": "Each list item as plain text, in visual order.",
#           "items": {
#             "type": "string"
#           },
#           "title": "Items",
#           "type": "array"
#         }
#       },
#       "required": [
#         "ordered"
#       ],
#       "title": "ListBlock",
#       "type": "object"
#     },
#     "Page": {
#       "description": "A single page of the document with optional header/footer and main content blocks.",
#       "properties": {
#         "page_number": {
#           "description": "1-based page index within the document.",
#           "minimum": 1,
#           "title": "Page Number",
#           "type": "integer"
#         },
#         "header": {
#           "description": "Top-of-page region; empty if none.",
#           "title": "Header",
#           "type": "string"
#         },
#         "footer": {
#           "description": "Bottom-of-page region; empty if none.",
#           "title": "Footer",
#           "type": "string"
#         },
#         "blocks": {
#           "description": "Main body content blocks for this page, in reading order, excluding header/footer.",
#           "items": {
#             "anyOf": [
#               {
#                 "$ref": "#/$defs/HeadingBlock"
#               },
#               {
#                 "$ref": "#/$defs/ParagraphBlock"
#               },
#               {
#                 "$ref": "#/$defs/ListBlock"
#               },
#               {
#                 "$ref": "#/$defs/TableBlock"
#               },
#               {
#                 "$ref": "#/$defs/CodeBlock"
#               },
#               {
#                 "$ref": "#/$defs/FigureBlock"
#               },
#               {
#                 "$ref": "#/$defs/FootnoteBlock"
#               }
#             ]
#           },
#           "title": "Blocks",
#           "type": "array"
#         }
#       },
#       "required": [
#         "page_number"
#       ],
#       "title": "Page",
#       "type": "object"
#     },
#     "ParagraphBlock": {
#       "description": "A paragraph of running body text.",
#       "properties": {
#         "kind": {
#           "const": "paragraph",
#           "default": "paragraph",
#           "description": "Discriminator tag for this block type.",
#           "title": "Kind",
#           "type": "string"
#         },
#         "text": {
#           "description": "Plain text content of the paragraph, preserving reading order.",
#           "title": "Text",
#           "type": "string"
#         }
#       },
#       "required": [
#         "text"
#       ],
#       "title": "ParagraphBlock",
#       "type": "object"
#     },
#     "TableBlock": {
#       "description": "A rectangular table represented as rows of cell text.",
#       "properties": {
#         "kind": {
#           "const": "table",
#           "default": "table",
#           "description": "Discriminator tag for this block type.",
#           "title": "Kind",
#           "type": "string"
#         },
#         "rows": {
#           "description": "2D array of table cells; each inner list is a row. All rows must have equal length.",
#           "items": {
#             "items": {
#               "type": "string"
#             },
#             "type": "array"
#           },
#           "title": "Rows",
#           "type": "array"
#         }
#       },
#       "title": "TableBlock",
#       "type": "object"
#     }
#   },
#   "description": "The full extracted document, organized by pages.",
#   "properties": {
#     "pages": {
#       "description": "List of pages in reading order.",
#       "items": {
#         "$ref": "#/$defs/Page"
#       },
#       "minItems": 1,
#       "title": "Pages",
#       "type": "array"
#     }
#   },
#   "required": [
#     "pages"
#   ],
#   "title": "Document",
#   "type": "object"
# }

# %%
from documentParseJson.md_extractor import extract_layout

pdf_bytes = ""
with open("./data_sources/BNM - Guidelines on Product Transparency and Disclosure.pdf", "rb") as f:
    pdf_bytes = f.read()

result = extract_layout(pdf=pdf_bytes, reasoning="minimal", verbosity="medium", model="gpt-5-mini", outdir="./bnm_test_2", max_workers=8, mode="image")
# Out:
# Processing 236 chunks with 8 workers...
# [image] Extracting image_0000_1.png[image] Extracting image_0003_1.png
#
# [image] Extracting image_0001_1.png
# [image] Extracting image_0004_1.png
# [image] Extracting image_0002_1.png
# [image] Extracting image_0005_1.png
# [image] Extracting image_0007_1.png
# [image] Extracting image_0006_1.png
# [image] Completed image_0001_1.png
# [image] Completed image_0005_1.png
# [image] Completed image_0002_1.png
# [image] Completed image_0000_1.png
# [image] Extracting image_0008_1.png
# [image] Extracting image_0009_1.png
# [image] Extracting image_0010_1.png
# [image] Extracting image_0011_1.png
# [image] Completed image_0006_1.png
# [image] Completed image_0004_1.png
# [image] Completed image_0007_1.png
# [image] Extracting image_0012_1.png
# [image] Extracting image_0013_1.png
# [image] Extracting image_0014_1.png
# [image] Completed image_0003_1.png
# [image] Extracting image_0015_1.png
# [image] Completed image_0008_1.png
# [image] Extracting image_0016_1.png
# [image] Completed image_0010_1.png
# [image] Completed image_0011_1.png
# [image] Extracting image_0017_1.png
# [image] Extracting image_0018_1.png
# [image] Completed image_0012_1.png
# [image] Extracting image_0019_1.png
# [image] Completed image_0013_1.png
# [image] Completed image_0009_1.png
# [image] Completed image_0014_1.png
# [image] Extracting image_0020_1.png
# [image] Extracting image_0021_1.png
# [image] Extracting image_0022_1.png
# [image] Completed image_0015_1.png
# [image] Extracting image_0023_1.png
# [image] Completed image_0022_1.png
# [image] Completed image_0016_1.png
# [image] Extracting image_0024_1.png
# [image] Extracting image_0025_1.png
# [image] Completed image_0017_1.png
# [image] Extracting image_0026_1.png
# [image] Completed image_0018_1.png
# [image] Extracting image_0027_1.png
# [image] Completed image_0020_1.png
# [image] Extracting image_0028_1.png
# [image] Completed image_0023_1.png
# [image] Completed image_0021_1.png
# [image] Extracting image_0029_1.png
# [image] Extracting image_0030_1.png
# [image] Completed image_0024_1.png
# [image] Extracting image_0031_1.png
# [image] Completed image_0027_1.png
# [image] Extracting image_0032_1.png
# [image] Completed image_0028_1.png
# [image] Completed image_0026_1.png
# [image] Extracting image_0033_1.png
# [image] Extracting image_0034_1.png
# [image] Completed image_0019_1.png
# [image] Extracting image_0035_1.png
# [image] Completed image_0025_1.png
# [image] Extracting image_0036_1.png[image] Completed image_0030_1.png
#
# [image] Completed image_0029_1.png
# [image] Extracting image_0037_1.png
# [image] Completed image_0032_1.png
# [image] Extracting image_0038_1.png
# [image] Extracting image_0039_1.png
# [image] Completed image_0031_1.png
# [image] Extracting image_0040_1.png
# [image] Completed image_0034_1.png
# [image] Completed image_0215_1.png
# [image] Extracting image_0219_1.png
# [image] Extracting image_0220_1.png
# [image] Completed image_0212_1.png
# [image] Completed image_0214_1.png
# [image] Extracting image_0221_1.png
# [image] Extracting image_0222_1.png
# [image] Completed image_0213_1.png
# [image] Completed image_0220_1.png
# [image] Extracting image_0223_1.png
# [image] Completed image_0216_1.png
# [image] Extracting image_0224_1.png
# [image] Completed image_0217_1.png
# [image] Extracting image_0225_1.png
# [image] Extracting image_0226_1.png
# [image] Completed image_0218_1.png
# [image] Extracting image_0227_1.png
# [image] Completed image_0224_1.png
# [image] Extracting image_0228_1.png
# [image] Completed image_0223_1.png
# [image] Completed image_0222_1.png
# [image] Extracting image_0229_1.png
# [image] Extracting image_0230_1.png
# [image] Completed image_0225_1.png
# [image] Extracting image_0231_1.png
# [image] Completed image_0221_1.png
# [image] Completed image_0226_1.png
# [image] Extracting image_0232_1.png
# [image] Completed image_0219_1.png
# [image] Extracting image_0233_1.png
# [image] Extracting image_0234_1.png
# [image] Completed image_0228_1.png
# [image] Extracting image_0235_1.png
# [image] Completed image_0229_1.png
# [image] Completed image_0232_1.png
# [image] Completed image_0227_1.png
# [image] Completed image_0234_1.png
# [image] Completed image_0235_1.png
# [image] Completed image_0230_1.png
# [image] Completed image_0233_1.png
# [image] Completed image_0231_1.png
# Done.
# Wrote bnm_test\document.json, bnm_test\document.md, bnm_test\sections.json
# Wrote usage statistics to usage.txt

# %%
import json

with open("./final_output_mini-minimal/sections.json", "r", encoding="utf-8") as f:
  data = json.loads(f.read())
  print(data[0]["content_md"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import json
# ----> 3 with open("./final_output_mini-minimal/sections.json", "r", encoding="utf-8") as f:
#       4   data = json.loads(f.read())
#       5   print(data[0]["content_md"])
#
# File d:\Projects\document_comparison\venv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './final_output_mini-minimal/sections.json'

# %%
from helpers.document_processor import DocumentProcessor

document_processor = DocumentProcessor()

with open("./test_dir/test_chunk/chunk_0090_to_0090.pdf", "rb") as f:
    result = document_processor.extract_with_pdfplumber(f)

# %%
result
# Out:
# 'Product Transparency and Disclosure 89 of 102\nKno Your Obligations\nN For this personal accident insurance takaful ou must pa a premium takaful\ncontribution of:\nStandard Cover\nAdditional Cover\nTotal premium / takaful contribution you must pay is\nYou also have topa the follo ing fees and charges:\nStamp duty\nCommission / akalah fee\nOther applicable charges\nOther Ke Terms\nou must provide complete and accurate information in the application form.\nou must disclose all material facts such as your occupation and personal pursuits.\nNote:This list isnon e haustive. ou should refer to the policy/certificate for the full list of\nterms and conditions.\nCan I cancel m polic certificate\nes. ou may cancel your policy/certificate at any time by giving a written notice to us.\nN Customer s Ackno ledgment\nEnsureyouarefillingthissectionyourselfandareawareofwhatyouareplacingyoursignaturefor.\nIacknowledge that FSPname hasprovided me withacopyofthePDS.\nIhavereadandunderstood thekeyinformation contained inthisPDS.\nName\nDate\nPage /\nIssued on: 2 December 2024'
