# %%
with open("./test_markdown\Wise - Eng T&C.md", "r", encoding="utf-8") as doc1, open("./test_markdown\Wise - BM T&S.md", "r", encoding="utf-8") as doc2:
    doc1_content = doc1.read()
    doc2_content = doc2.read()
    # for line in doc1.readlines():
    #     if line.strip() == "":
    #         continue
    #     doc1_content += line.strip() + "\n"

    # for line in doc2.readlines():
    #     if line.strip() == "":
    #         continue
    #     doc2_content += line.strip() + "\n"

# %%
from helpers.document_processor import DocumentProcessor
from langchain.prompts import ChatPromptTemplate

document_processor = DocumentProcessor()

# with open(".\multilingual_docs\Essential\hlb-essential-credit-card-tnc-en.pdf", "rb") as doc1_file, open(".\multilingual_docs\Essential\hlb-essential-credit-card-tnc-bm.pdf", "rb") as doc2_file:
#     doc1_content = document_processor.extract_filtered_content(doc1_file.read())
#     doc2_content = document_processor.extract_filtered_content(doc2_file.read())

# instruction = """You are a meticulous linguistic analyst with extraordinary attention to detail, specializing in document comparison across different languages.

# Your task is to create an EXHAUSTIVE and COMPREHENSIVE list of ALL discrepancies between the English and Bahasa Malaysia versions of a legal document.

# Here are the two documents you need to compare:

# <document1>
# {doc1}
# </document1>

# ## END OF DOCUMENT 1 ##

# <document2>
# {doc2}
# </document2>

# ## END OF DOCUMENT 2 ##

# ## ULTRA-PRECISE DETECTION METHODOLOGY ##

# Your goal is to identify AS MANY discrepancies as possible between these documents. Use your reasoning capabilities to detect ANY and ALL differences, no matter how small or seemingly insignificant. A complete analysis should find dozens of discrepancies in complex legal documents.

# ## CRITICAL DETECTION REQUIREMENTS ##

# 1. WORD-BY-WORD COMPARISON:
#    - Compare EVERY word in each sentence, one by one
#    - Identify ANY word present in one language but missing in the other (e.g., "GSC" present in BM but missing in English)
#    - Check each word for spelling errors (e.g., "mengunakan" vs correct "menggunakan")
#    - Don't assume sentences with similar meaning have equivalent words

# 2. MULTIPLE DISCREPANCIES PER SENTENCE:
#    - A single sentence can contain MULTIPLE discrepancies
#    - After finding one difference in a sentence, continue analyzing the same sentence for additional differences
#    - Flag EACH difference separately, even if they occur in the same sentence or paragraph

# 3. SPELLING AND GRAMMAR VERIFICATION:
#    - Check EVERY word for correct spelling in both languages
#    - Identify ALL spelling mistakes (e.g., "mengunakan" instead of "menggunakan")
#    - Flag grammatical errors that could affect meaning or clarity

# 4. FORMATTING DIFFERENCES:
#    - Different numbering systems (e.g., [a,b,c] vs [i,ii,iii])
#    - Different bullet point styles
#    - Different indentation or paragraph structures
#    - Different table layouts or formatting

# 5. MISSING ELEMENTS:
#    - Words present in one language but missing in the other
#    - Phrases present in one language but missing in the other
#    - Entire sentences present in one language but missing in the other
#    - Parenthetical phrases present in one language but not the other
#    - Brand names, product names, or proper nouns missing in either version

# 6. SMALL BUT SIGNIFICANT DIFFERENCES:
#    - Different articles (a, an, the)
#    - Different prepositions
#    - Different conjunctions (and, or)
#    - Different punctuation that might affect meaning
#    - Different pronouns or references

# 7. TECHNICAL ELEMENTS:
#    - Different product names or abbreviations
#    - Different numerical values or units
#    - Different dates or time references
#    - Different section or clause references

# For EACH discrepancy you find, provide:
# - Location: Precise location in the document (section, clause, paragraph)
# - Content from Document 1 with differences highlighted
# - Content from Document 2 with differences highlighted
# - Brief explanation of the discrepancy, including EXACTLY what words are missing, misspelled, or different

# After your analysis, format your response as a JSON object with this structure:

# {{
#   "flags": [
#     {{
#       "location": "Precise location in the document",
#       "doc1": {{
#         "content": "Content from Document 1 with <span style=\"color: red\">highlighted difference</span>"
#       }},
#       "doc2": {{
#         "content": "Content from Document 2 with <span style=\"color: red\">highlighted difference</span>"
#       }},
#       "explanation": "Comprehensive explanation of ALL discrepancies found in this sentence/section, listing EACH difference including missing words, misspellings, grammatical errors, formatting issues, etc."
#     }}
#   ]
# }}

# ## YOUR ANALYSIS PROCESS MUST INCLUDE ##

# 1. WORD-BY-WORD CHECKING:
#    - For each sentence pair, create a mental mapping of each word and check if any words are missing in either language
#    - Do not skip any words, regardless of their perceived importance
#    - Specially check for product names, brand names, and proper nouns (like "GSC")

# 2. MULTI-PASS ANALYSIS:
#    - First pass: Check for structural and clear content differences
#    - Second pass: Check for missing words and phrases
#    - Third pass: Check for spelling errors and grammatical issues
#    - Fourth pass: Check for punctuation and formatting differences

# 3. EXHAUSTIVE CONTINUATION:
#    - After finding one discrepancy in a sentence, DO NOT STOP
#    - Continue examining the SAME sentence for additional discrepancies
#    - Flag each distinct issue separately

# REMEMBER:
# - CHECK EVERY SINGLE WORD in every sentence
# - FLAG EVERY MISSING WORD, even when the overall meaning seems preserved
# - IDENTIFY MULTIPLE DISCREPANCIES in the same sentence or paragraph
# - CHECK FOR SPELLING ERRORS in both languages
# - EXAMINE ALL FORMATTING and numbering systems
# - IDENTIFY EVERY INSTANCE where content exists in one language but not in the other
# - FLAG ALL differences in punctuation, articles, prepositions that might affect meaning
# - THERE CAN BE MULTIPLE DISCREPANCIES in a single flag
# - BE EXTREMELY THOROUGH

# A TRULY COMPREHENSIVE ANALYSIS WILL IDENTIFY AT LEAST 20 to 50 DISCREPANCIES."""

# instruction = """You are a meticulous linguistic analyst comparing English and Bahasa Malaysia versions of a legal document.

# Your task is to create a comprehensive list of ALL discrepancies between the two documents.

# Here are the two documents:

# <ENGLISH_VERSION>
# {doc1}
# </ENGLISH_VERSION>

# <BAHASA_MALAYSIA_VERSION>
# {doc2}
# </BAHASA_MALAYSIA_VERSION>

# ## KEY ANALYSIS REQUIREMENTS ##

# 1. Examine both documents word-by-word, comparing each sentence in both languages
# 2. Create a separate flag for EACH distinct discrepancy, even within the same sentence
# 3. Pay special attention to:
#    - Missing words in either language (e.g., "HLB QR Pay" vs just "QR Pay")
#    - Spelling errors (e.g., "mengunakan" instead of "menggunakan")
#    - Formatting and numbering differences
#    - Brand names and technical terms
# 4. Both documents should reflect the exact same meaning, so if even a word is missing in one version, it should be flagged
# 5. When highlighting differences:
#    - Highlight ONLY the specific word or element that differs
#    - For missing words, highlight the word in the version where it exists

# After your analysis, provide a JSON object with this structure:

# {{
#   "total": "Total number of discrepancies found",
#   "flags": [
#     {{
#       "location": "Precise location in the document",
#       "doc1": {{
#         "content": "Content from Document 1 with <span style=\"color: red\">highlighted difference</span>"
#       }},
#       "doc2": {{
#         "content": "Content from Document 2 with <span style=\"color: red\">highlighted difference</span>"
#       }},
#       "explanation": "Brief explanation of this specific discrepancy"
#     }}
#   ]
# }}

# Important: Your analysis should identify dozens of discrepancies, including multiple separate discrepancies within the same sentence when they exist."""

# instruction = """You are a meticulous linguistic analyst comparing English and Bahasa Malaysia versions of a legal document.

# Your task is to create a comprehensive list of ALL discrepancies between the two documents.

# 1. Examine both documents word-by-word, comparing each sentence in both languages in sequential order
# 2. Compare documents section by section, paragraph by paragraph, and sentence by sentence to maintain proper alignment
# 3. **CRITICAL BIDIRECTIONAL ANALYSIS:** Check for discrepancies in BOTH directions systematically:
#    - English → Bahasa Malaysia: What's missing or wrong in the BM version?
#    - Bahasa Malaysia → English: What's missing or wrong in the English version?
# 4. For efficiency, combine multiple discrepancies from the same sentence or paragraph under one flag, but list each individual discrepancy within that flag
# 4. Pay special attention to these specific discrepancy patterns:
#    **Missing Content (CHECK BOTH DIRECTIONS):**
#    - Missing words in either language (e.g., "HLB" missing, "feature" missing, "GSC" missing)
#    - Missing entire sentences or clauses in either version (e.g., entire clause missing in English but present in BM)
#    - Missing translations of phrases (e.g., "(as defined herein)" missing in BM, or "seperti ditakrifkan di sini" missing in English)
#    - Missing conjunctions or connecting words ("and", "atau", "T&S ini")
#    - Missing descriptive words ("Eligible", "Layak", "following transactions")
   
#    **Multiple Issues in Single Locations:**
#    - Scan each clause for multiple simultaneous issues (missing words + wrong translations + structural differences)
#    - Don't stop at first discrepancy found - continue scanning the entire clause/sentence
#    - Check for combinations like: missing word + spelling error + wrong translation in same location
   
#    **Spelling & Language Errors:**
#    - Spelling errors (e.g., "mengunakan" instead of "menggunakan", "Jumalah" instead of "Jumlah")
#    - Wrong word translations (e.g., "Codes" translated as "Kad" instead of proper translation)
#    - Language mixing (English words used in BM version, e.g., "JULY" in BM document)
   
#    **Structural & Formatting Issues:**
#    - Different clause numbering between versions
#    - Different table references (Table 1 vs Clause 1(b))
#    - Inconsistent terminology usage across documents
#    - Word repetition errors (e.g., "ini ini")
   
#    **Content Interpretation Differences:**
#    - Different amounts or percentages (e.g., RM1500 vs RM80, 0.20% vs 0.2%)
#    - Different website links between versions
#    - Inaccurate translations that change meaning (e.g., "after reversal" vs "daripada Pembalikan")
#    - Different transaction categories or descriptions
#    - Additional words in one version that change meaning (e.g., extra "Transaksi" word)
#    - Different interpretations of same concept (e.g., "Pembelanjaan Runcit atau Perbelanjaan Runcit")
#    - Missing qualifiers that change scope (e.g., "Principal Cardholder" vs just "Cardholder")
   
#    **Punctuation & Grammar:**
#    - Missing commas, periods, or other punctuation
#    - Different sentence structures that change meaning
#    - Inconsistent use of quotation marks or brackets
   
#    **Standardization Issues:**
#    - Inconsistent translation of standard terms (e.g., "Not applicable" as "Tidak Berkenaan" vs "Tidak Sah")
#    - Different word choices for same concept (e.g., "tapak/halaman" vs "laman")
# 4. Both documents should reflect the exact same meaning and structure in the same order, so if even a word is missing in one version, it should be flagged
# 5. When highlighting differences:
#    - Highlight ONLY the specific word or element that differs
#    - For missing words, highlight the word in the version where it exists

# After your analysis, provide a JSON object with this structure:

# ```json
# {{
#   "total": "Total number of discrepancy flags found",
#   "flags": [
#     {{
#       "location": "Precise location in the document (e.g., 'Paragraph 2, Sentence 1' or 'Section 3.1')",
#       "doc1": {{
#         "content": "Content from Document 1 with <span style=\"color: red\">highlighted differences</span>"
#       }},
#       "doc2": {{
#         "content": "Content from Document 2 with <span style=\"color: red\">highlighted differences</span>"
#       }},
#       "discrepancies": [
#         "List each individual discrepancy found in this location",
#         "Another discrepancy in the same sentence/paragraph",
#         "Third discrepancy if present"
#       ],
#       "explanation": "Brief explanation of all discrepancies in this location"
#     }}
#   ]
# }}
# ```

# Important: Your analysis should identify dozens of discrepancies, including multiple separate discrepancies within the same sentence when they exist.

# **CRITICAL:** This is a highly sensitive legal document analysis. Do not worry about output length - generate ALL discrepancies found, no matter how many there are. Every single mismatch, missing word, spelling error, formatting difference, amount discrepancy, structural variation, or translation inconsistency must be documented. 

# **BIDIRECTIONAL SCANNING:** Always check BOTH English→BM AND BM→English for missing content. Many discrepancies involve content present in one version but missing in the other.

# Completeness is more important than brevity.

# ---

# Here are the two documents:

# **ENGLISH_VERSION:**
# {doc1}

# **BAHASA_MALAYSIA_VERSION:**
# {doc2}"""

# instruction = """You are a meticulous linguistic analyst comparing English and Bahasa Malaysia versions of a legal document.

# Your task is to create a comprehensive list of ALL discrepancies between the two documents.

# 1. Examine both documents word-by-word, comparing each sentence in both languages in sequential order
# 2. Compare documents section by section, paragraph by paragraph, and sentence by sentence to maintain proper alignment
# 3. **CRITICAL BIDIRECTIONAL ANALYSIS:** Check for discrepancies in BOTH directions systematically:
#    - English → Bahasa Malaysia: What's missing or wrong in the BM version?
#    - Bahasa Malaysia → English: What's missing or wrong in the English version?
# 4. For efficiency, combine multiple discrepancies from the same sentence or paragraph under one flag, but list each individual discrepancy within that flag
# 4. Pay special attention to these specific discrepancy patterns:
#    **Missing Content (CHECK BOTH DIRECTIONS):**
#    - Missing words in either language (e.g., "HLB" missing, "feature" missing, "GSC" missing)
#    - **Missing translations of individual words within translated sentences** (e.g., "Eligible" missing in BM version while rest of sentence is translated)
#    - Missing entire sentences or clauses in either version (e.g., entire clause missing in English but present in BM)
#    - Missing translations of phrases (e.g., "(as defined herein)" missing in BM, or "seperti ditakrifkan di sini" missing in English)
#    - Missing conjunctions or connecting words ("and", "atau", "T&S ini")
#    - Missing descriptive words ("Eligible", "Layak", "following transactions")
#    - **Partial translations where some words are translated but key descriptive words are omitted**
   
#    **Multiple Issues in Single Locations:**
#    - Scan each clause for multiple simultaneous issues (missing words + wrong translations + structural differences)
#    - Don't stop at first discrepancy found - continue scanning the entire clause/sentence
#    - Check for combinations like: missing word + spelling error + wrong translation in same location
   
#    **Spelling & Language Errors:**
#    - Spelling errors (e.g., "mengunakan" instead of "menggunakan", "Jumalah" instead of "Jumlah")
#    - Wrong word translations (e.g., "Codes" translated as "Kad" instead of proper translation)
#    - Language mixing (English words used in BM version, e.g., "JULY" in BM document)
   
#    **Structural & Formatting Issues:**
#    - Different clause numbering between versions
#    - Different table references (Table 1 vs Clause 1(b))
#    - Inconsistent terminology usage across documents
#    - Word repetition errors (e.g., "ini ini")
   
#    **Content Interpretation Differences:**
#    - Different amounts or percentages (e.g., RM1500 vs RM80, 0.20% vs 0.2%)
#    - Different website links between versions
#    - Inaccurate translations that change meaning (e.g., "after reversal" vs "daripada Pembalikan")
#    - Different transaction categories or descriptions
#    - Additional words in one version that change meaning (e.g., extra "Transaksi" word)
#    - Different interpretations of same concept (e.g., "Pembelanjaan Runcit atau Perbelanjaan Runcit")
#    - Missing qualifiers that change scope (e.g., "Principal Cardholder" vs just "Cardholder")
   
#    **Punctuation & Grammar:**
#    - Missing commas, periods, or other punctuation
#    - Different sentence structures that change meaning
#    - Inconsistent use of quotation marks or brackets
   
#    **Standardization Issues:**
#    - Inconsistent translation of standard terms (e.g., "Not applicable" as "Tidak Berkenaan" vs "Tidak Sah")
#    - Different word choices for same concept (e.g., "tapak/halaman" vs "laman")
# 4. Both documents should reflect the exact same meaning and structure in the same order, so if even a word is missing in one version, it should be flagged
# 5. When highlighting differences:
#    - Highlight ONLY the specific word or element that differs
#    - For missing words, highlight the word in the version where it exists

# After your analysis, provide a JSON object with this structure:

# ```json
# {{
#   "total": "Total number of discrepancy flags found",
#   "flags": [
#     {{
#       "location": "Precise location in the document (e.g., 'Paragraph 2, Sentence 1' or 'Section 3.1')",
#       "doc1": {{
#         "content": "Content from Document 1 with <span style=\"color: red\">highlighted differences</span>"
#       }},
#       "doc2": {{
#         "content": "Content from Document 2 with <span style=\"color: red\">highlighted differences</span>"
#       }},
#       "discrepancies": [
#         "List each individual discrepancy found in this location",
#         "Another discrepancy in the same sentence/paragraph",
#         "Third discrepancy if present"
#       ],
#       "explanation": "Brief explanation of all discrepancies in this location"
#     }}
#   ]
# }}
# ```

# Important: Your analysis should identify dozens of discrepancies, including multiple separate discrepancies within the same sentence when they exist.

# **CRITICAL:** This is a highly sensitive legal document analysis. Do not worry about output length - generate ALL discrepancies found, no matter how many there are. Every single mismatch, missing word, spelling error, formatting difference, amount discrepancy, structural variation, or translation inconsistency must be documented. 

# **SUTERA-LEVEL DETECTION:** Based on actual review findings, expect to find dozens of discrepancies including missing brand names, incorrect translations, different numbering systems, wrong amounts, inconsistent terminology, structural differences, AND complex multi-issue clauses where multiple problems exist in single locations. Scan each clause thoroughly - don't stop after finding the first issue.

# **BIDIRECTIONAL SCANNING:** Always check BOTH English→BM AND BM→English for missing content. Many discrepancies involve content present in one version but missing in the other. **Pay special attention to partial translations where most of a sentence is translated correctly but individual qualifying words like "Eligible", "Principal", "Authorized", etc. are omitted.**

# Completeness is more important than brevity.

# ---

# Here are the two documents:

# **ENGLISH_VERSION:**
# {doc1}

# **BAHASA_MALAYSIA_VERSION:**
# {doc2}
# """

# v32 Working
# instruction = """You are a meticulous linguistic analyst comparing English and Bahasa Malaysia versions of a legal document.

# Your task is to create a comprehensive list of ALL discrepancies between the two documents.

# 1. Examine both documents with **WORD-LEVEL PRECISION** - compare every single word in corresponding sentences, even when the overall meaning appears equivalent
# 2. Compare documents section by section, paragraph by paragraph, and sentence by sentence to maintain proper alignment
# 3. **CRITICAL BIDIRECTIONAL ANALYSIS:** Check for discrepancies in BOTH directions systematically:
#    - English → Bahasa Malaysia: What's missing or wrong in the BM version?
#    - Bahasa Malaysia → English: What's missing or wrong in the English version?
# 4. For efficiency, combine multiple discrepancies from the same sentence or paragraph under one flag, but list each individual discrepancy within that flag

# 5. Pay special attention to these specific discrepancy patterns:
#    **Missing Content:**
#    - Missing words in either language
#    - Missing translations of individual words within translated sentences
#    - Additional descriptive words in one version not translated to the other
#    - Asymmetric translations where one version has more qualifying words
#    - Missing entire sentences or clauses in either version
#    - Missing translations of phrases
#    - Missing conjunctions or connecting words
#    - Partial translations where some words are translated but key descriptive words are omitted
   
#    **Spelling & Language Errors:**
#    - Spelling errors in either language
#    - Wrong word translations
#    - Language mixing (English words used in BM version or vice versa)
   
#    **Structural & Formatting Issues:**
#    - Different clause numbering between versions
#    - Different numbering systems within lists
#    - Different table/section references
#    - Inconsistent terminology usage across documents
#    - Word repetition errors
   
#    **Content Interpretation Differences:**
#    - Different amounts or percentages
#    - Different website links between versions
#    - Inaccurate translations that change meaning
#    - Different transaction categories or descriptions
#    - Additional words in one version that change meaning
#    - Different interpretations of same concept
#    - Missing qualifiers that change scope
   
#    **Punctuation & Grammar:**
#    - Missing commas, periods, or other punctuation
#    - Different sentence structures that change meaning
#    - Inconsistent use of quotation marks or brackets
   
#    **Standardization Issues:**
#    - Inconsistent translation of standard terms
#    - Different word choices for same concept

# 6. **WORD-LEVEL ANALYSIS REQUIRED:** Even when sentences have the same general meaning, flag any missing or different words between versions. Perfect translation accuracy means EVERY word should have its equivalent representation, regardless of whether the sentence meaning is preserved

# 7. Both documents should reflect the exact same meaning and structure in the same order, with perfect translations - flag even the smallest discrepancies including:
#    - Single character differences
#    - Word order variations that change meaning
#    - Missing or extra words that alter context
#    - Incomplete translations where some words are translated but others are omitted
#    - Unbalanced translations where one version has additional qualifying words
#    - Any missing word even if the sentence meaning remains clear
#    - Inconsistent translations of the same term throughout the document
#    - Different interpretations that could mislead readers

# 8. When highlighting differences:
#    - Highlight ONLY the specific word or element that differs
#    - For missing words, highlight the word in the version where it exists
#    - For partial translations, highlight the missing word in the complete version and note its absence in the incomplete version
#    - For asymmetric translations, highlight the additional word(s) in the more detailed version and note the absence in the simpler version
#    - Check for discrepancies in BOTH directions (English→Bahasa Malaysia AND Bahasa Malaysia→English)
#    - Ensure no discrepancy is missed from either document
#    - For complex clauses: Scan the ENTIRE clause multiple times to catch all issues, don't stop after finding one discrepancy
#    - Word-by-word comparison: Compare each word in equivalent sentences to catch missing individual word translations
#    - FLAG EVEN MINOR WORD OMISSIONS: Even if sentence meaning is preserved, flag any missing words for complete accuracy

# After your analysis, provide a JSON object with this structure:

# ```json
# {{
#   "total": "Total number of discrepancy flags found",
#   "flags": [
#     {{
#       "location": "Precise location in the document (e.g., 'Paragraph 2, Sentence 1' or 'Section 3.1')",
#       "doc1": {{
#         "content": "Content from Document 1 with <span style=\"color: red\">highlighted differences</span>"
#       }},
#       "doc2": {{
#         "content": "Content from Document 2 with <span style=\"color: red\">highlighted differences</span>"
#       }},
#       "discrepancies": [
#         "1. List each individual discrepancy found in this location",
#         "2. Another discrepancy in the same sentence/paragraph",
#         "3. Third discrepancy if present"
#       ],
#       "explanation": "Brief explanation of all discrepancies in this location"
#     }}
#   ]
# }}
# ```

# **CRITICAL:** This is a highly sensitive legal document analysis. Do not worry about output length - generate ALL discrepancies found, no matter how many there are. Every single mismatch, missing word, spelling error, formatting difference, amount discrepancy, structural variation, or translation inconsistency must be documented. 

# Based on actual review findings, expect to find dozens of discrepancies including missing brand names, incorrect translations, different numbering systems, wrong amounts, inconsistent terminology, structural differences, AND complex multi-issue clauses where multiple problems exist in single locations. Scan each clause thoroughly - don't stop after finding the first issue.

# **BIDIRECTIONAL SCANNING:** Always check BOTH English→BM AND BM→English for missing content. Many discrepancies involve content present in one version but missing in the other. **Pay EXTRA attention to missing translations in the BM version - this is a common issue where English descriptive words are frequently omitted in Bahasa Malaysia translations.**

# **TABLE CONTENT FOCUS:** For tables, compare only the content and data within the tables - do not flag differences in layout, formatting, or visual structure. Focus solely on textual content, amounts, and data accuracy.

# **WORD-LEVEL PRECISION REQUIRED:** Flag ANY missing word, even if the overall sentence meaning is clear. Legal documents require perfect word-for-word accuracy, not just conceptual equivalence. A missing adjective, adverb, or descriptive word must be flagged regardless of whether the sentence still makes sense.

# **ASYMMETRIC TRANSLATION DETECTION:** Also flag when one version has MORE qualifying words than the other. Both under-translation and over-specification must be detected.

# Completeness is more important than brevity.

# ---

# Here are the two documents:

# **ENGLISH_VERSION:**
# {doc1}

# **BAHASA_MALAYSIA_VERSION:**
# {doc2}"""

# v41
# instruction = """You are a meticulous linguistic analyst comparing English and Bahasa Malaysia versions of a legal document.

# Your task is to create a comprehensive list of ALL discrepancies between the two documents.

# 1. Compare both documents word-by-word, sentence by sentence
# 2. Check for discrepancies in BOTH directions:
#    - What's in English but missing/wrong in BM?
#    - What's in BM but missing/wrong in English?
# 3. Flag every single difference, no matter how small
# 4. Combine multiple discrepancies from the same location under one flag

# **Detection Requirements:**

# **Missing Words/Translations:**
# - Missing individual words (e.g., "HLB" in "HLB QR Pay" vs just "QR Pay")
# - Missing descriptive words (e.g., "Eligible" missing in BM version)
# - Missing translations of phrases (e.g., "(as defined herein)" missing)
# - Missing entire sentences or clauses

# **Translation Errors:**
# - Wrong word translations (e.g., "Codes" translated as "Kad" instead of proper translation)
# - Misleading translations that change meaning
# - Amount/percentage discrepancies (e.g., RM1500 vs RM80, 0.20% vs 0.2%)
# - Language mixing (e.g., English "JULY" in BM version)

# **Spelling & Grammar:**
# - Spelling errors (e.g., "mengunakan" should be "menggunakan")
# - Word repetition (e.g., "ini ini" repetition)
# - Missing punctuation (commas, quotation marks)

# **Structural Issues:**
# - Different cross-references (e.g., "Table 1" vs "Clause 1(b)")
# - Different clause numbering between versions
# - Missing entire sections in one version
# - Duplicate content in one version only

# **Inconsistencies:**
# - Same term translated differently within document
# - Non-standardized translations (e.g., "Not applicable" as both "Tidak Berkenaan" and "Tidak Sah")
# - Different website links between versions
# - Inconsistent terminology usage

# After your analysis, provide a JSON object with this structure:

# ```json
# {{
#   "total": "Total number of discrepancy flags found",
#   "flags": [
#     {{
#       "location": "Precise location in the document",
#       "doc1": {{
#         "content": "Content from Document 1 with <span style=\"color: red\">highlighted differences</span>"
#       }},
#       "doc2": {{
#         "content": "Content from Document 2 with <span style=\"color: red\">highlighted differences</span>"
#       }},
#       "discrepancies": [
#         "List each individual discrepancy found in this location"
#       ],
#       "explanation": "Brief explanation of all discrepancies in this location"
#     }}
#   ]
# }}
# ```

# **CRITICAL INSTRUCTIONS:**

# - Generate ALL discrepancies found - do not limit output length
# - Check every word, punctuation mark, and number
# - Flag missing words even if sentence meaning is clear  
# - Flag asymmetric translations (one version more detailed than other)
# - Flag wrong cross-references, amounts, or terminology
# - Flag inconsistent translations of the same term
# - For tables, compare content only (not layout)
# - Pay extra attention to missing translations in BM version

# ---

# Here are the two documents:

# **ENGLISH_VERSION:**
# {doc1}

# **BAHASA_MALAYSIA_VERSION:**
# {doc2}"""

# 42
# instruction = """You are a meticulous linguistic analyst comparing English and Bahasa Malaysia versions of a legal document.

# Your task is to create a comprehensive list of ALL discrepancies between the two documents.

# 1. Compare both documents word-by-word, sentence by sentence
# 2. Check for discrepancies in BOTH directions:
#    - What's in English but missing/wrong in BM?
#    - What's in BM but missing/wrong in English?
# 3. Flag every single difference, no matter how small
# 4. Combine multiple discrepancies from the same location under one flag

# **Detection Requirements:**

# **Missing Words/Translations:**
# - Missing individual words (e.g., "HLB QR Pay" vs just "QR Pay", "Eligible Merchant Category" vs just "Kategori Peniaga")
# - Missing descriptive words (e.g., "Principal Cardholder" vs just "Cardholder", "Calendar month" vs just "month")
# - Missing translations of phrases (e.g., "(as defined herein)" missing in BM, "seperti ditakrifkan di sini" missing in English)
# - Missing entire sentences or clauses (e.g., entire "Mata Ganjaran" clause missing in English version)
# - Missing conjunctions (e.g., "and/atau" vs just "atau", missing "T&S ini")

# **Translation Errors:**
# - Wrong word translations (e.g., "Codes" translated as "Kad" instead of proper translation, "Not applicable" as "Tidak Sah" instead of "Tidak Berkenaan")
# - Misleading translations that change meaning (e.g., "after reversal of RM20" vs "selepas tolak RM20 daripada Pembalikan")
# - Amount/percentage discrepancies (e.g., RM1500 vs RM80, 0.20% vs 0.2%)
# - Language mixing (e.g., English "JULY" in BM version, BM words in English version)
# - Wrong interpretations (e.g., "Principal Cardholder" vs just "Pemegang Kad" instead of "Pemegang Kad Utama")

# **Spelling & Grammar:**
# - Spelling errors (e.g., "mengunakan" should be "menggunakan", "Jumalah" should be "Jumlah")
# - Word repetition (e.g., "ini ini" unnecessary repetition)
# - Missing punctuation (commas, quotation marks like missing "for more information")
# - Grammar issues that change meaning

# **Structural Issues:**
# - Different cross-references (e.g., "listed in Table 1" vs "listed in Clause 1(b)")
# - Different clause numbering between versions
# - Missing entire sections in one version (e.g., whole clauses present in one but not the other)
# - Duplicate content in one version only (e.g., "Jadual 1" appearing twice)
# - Different table/section organization

# **Inconsistencies:**
# - Same term translated differently within document (e.g., "awarded" as both "diberi" and "dianugerahkan")
# - Non-standardized translations (e.g., "tapak/halaman" vs "laman" for website)
# - Different website links between versions
# - Inconsistent terminology usage (e.g., "i.e" vs "iaitu")
# - Different transaction categories (e.g., "Dining and Groceries" vs "Jamu Selera dan barangan Runcit & Keperluan")

# After your analysis, provide a JSON object with this structure:

# ```json
# {{
#   "total": "Total number of discrepancy flags found",
#   "flags": [
#     {{
#       "location": "Precise location in the document",
#       "doc1": {{
#         "content": "Content from Document 1 with <span style=\"color: red\">highlighted differences</span>"
#       }},
#       "doc2": {{
#         "content": "Content from Document 2 with <span style=\"color: red\">highlighted differences</span>"
#       }},
#       "discrepancies": [
#         "List each individual discrepancy found in this location"
#       ],
#       "explanation": "Brief explanation of all discrepancies in this location"
#     }}
#   ]
# }}
# ```

# **CRITICAL INSTRUCTIONS:**

# - Generate ALL discrepancies found - do not limit output length
# - Check every word, punctuation mark, and number
# - Flag missing words even if sentence meaning is clear  
# - Flag asymmetric translations (one version more detailed than other)
# - Flag wrong cross-references, amounts, or terminology
# - Flag inconsistent translations of the same term
# - For tables, compare content only (not layout)
# - Pay extra attention to missing translations in BM version

# ---

# Here are the two documents:

# **ENGLISH_VERSION:**
# {doc1}

# **BAHASA_MALAYSIA_VERSION:**
# {doc2}
# """

instruction = """You are a meticulous linguistic analyst comparing English and Bahasa Malaysia versions of a legal document.

Your task is to create a comprehensive list of ALL discrepancies between the two documents.

1. Examine both documents with **WORD-LEVEL PRECISION** - compare every single word in corresponding sentences, even when the overall meaning appears equivalent
2. Compare documents section by section, paragraph by paragraph, and sentence by sentence to maintain proper alignment
3. **CRITICAL BIDIRECTIONAL ANALYSIS:** Check for discrepancies in BOTH directions systematically:
   - English → Bahasa Malaysia: What's missing or wrong in the BM version?
   - Bahasa Malaysia → English: What's missing or wrong in the English version?
4. For efficiency, combine multiple discrepancies from the same sentence or paragraph under one flag, but list each individual discrepancy within that flag

5. Pay special attention to these specific discrepancy patterns:
   **Missing Content:**
   - Missing words in either language
   - Missing translations of individual words within translated sentences
   - Additional descriptive words in one version not translated to the other
   - Asymmetric translations where one version has more qualifying words
   - Missing entire sentences or clauses in either version
   - Missing translations of phrases
   - Missing conjunctions or connecting words
   - Partial translations where some words are translated but key descriptive words are omitted
   
   **Spelling & Language Errors:**
   - Spelling errors in either language
   - Wrong word translations
   - Language mixing (English words used in BM version or vice versa)
   
   **Structural & Formatting Issues:**
   - Different clause numbering between versions
   - Different numbering systems within lists
   - Different table/section references
   - Inconsistent terminology usage across documents
   - Word repetition errors
   
   **Content Interpretation Differences:**
   - Different amounts or percentages
   - Different website links between versions
   - Inaccurate translations that change meaning
   - Different transaction categories or descriptions
   - Additional words in one version that change meaning
   - Different interpretations of same concept
   - Missing qualifiers that change scope
   
   **Punctuation & Grammar:**
   - Missing commas, periods, or other punctuation
   - Different sentence structures that change meaning
   - Inconsistent use of quotation marks or brackets
   
   **Standardization Issues:**
   - Inconsistent translation of standard terms
   - Different word choices for same concept

6. **WORD-LEVEL ANALYSIS REQUIRED:** Even when sentences have the same general meaning, flag any missing or different words between versions. Perfect translation accuracy means EVERY word should have its equivalent representation, regardless of whether the sentence meaning is preserved

7. Both documents should reflect the exact same meaning and structure in the same order, with perfect translations - flag even the smallest discrepancies including:
   - Single character differences
   - Word order variations that change meaning
   - Missing or extra words that alter context
   - Incomplete translations where some words are translated but others are omitted
   - Unbalanced translations where one version has additional qualifying words
   - Any missing word even if the sentence meaning remains clear
   - Inconsistent translations of the same term throughout the document
   - Different interpretations that could mislead readers

8. **COMPLETE LINE CAPTURE MANDATORY:** When identifying corresponding sentences or clauses for comparison, you MUST capture and compare the ENTIRE line content from absolute beginning to absolute end, including all terminal words, conjunctions, and punctuation. Never truncate lines or stop before trailing conjunctions like "and", "or", semicolons, or any end-of-line elements.

9. **EXHAUSTIVE MULTIPLE DISCREPANCY DETECTION:** Within each sentence or clause, you MUST identify and flag ALL discrepancies present, not just the first one found. Conduct multiple passes through each sentence to ensure no discrepancy is missed. A single sentence may contain multiple different types of errors (missing words, wrong translations, spelling errors, punctuation differences, etc.) - document every single one. Do not stop analysis after finding one discrepancy; continue scanning the entire sentence until all issues are identified.

10. When highlighting differences:
   - Highlight ONLY the specific word or element that differs
   - For missing words, highlight the word in the version where it exists
   - For partial translations, highlight the missing word in the complete version and note its absence in the incomplete version
   - For asymmetric translations, highlight the additional word(s) in the more detailed version and note the absence in the simpler version
   - Check for discrepancies in BOTH directions (English→Bahasa Malaysia AND Bahasa Malaysia→English)
   - Ensure no discrepancy is missed from either document
   - For complex clauses: Scan the ENTIRE clause multiple times to catch all issues, don't stop after finding one discrepancy
   - Word-by-word comparison: Compare each word in equivalent sentences to catch missing individual word translations
   - FLAG EVEN MINOR WORD OMISSIONS: Even if sentence meaning is preserved, flag any missing words for complete accuracy

After your analysis, provide a JSON object with this structure:

```json
{{
  "total": "Total number of discrepancy flags found",
  "flags": [
    {{
      "location": "Precise location in the document (e.g., 'Paragraph 2, Sentence 1' or 'Section 3.1')",
      "doc1": {{
        "content": "Content from Document 1 with <span style=\"color: red\">highlighted differences</span>"
      }},
      "doc2": {{
        "content": "Content from Document 2 with <span style=\"color: red\">highlighted differences</span>"
      }},
      "discrepancies": [
        "1. List each individual discrepancy found in this location",
        "2. Another discrepancy in the same sentence/paragraph",
        "3. Third discrepancy if present"
      ],
      "explanation": "Brief explanation of all discrepancies in this location"
    }}
  ]
}}
```

**CRITICAL:** This is a highly sensitive legal document analysis. Do not worry about output length - generate ALL discrepancies found, no matter how many there are. Every single mismatch, missing word, spelling error, formatting difference, amount discrepancy, structural variation, or translation inconsistency must be documented. 

Based on actual review findings, expect to find dozens of discrepancies including missing brand names, incorrect translations, different numbering systems, wrong amounts, inconsistent terminology, structural differences, AND complex multi-issue clauses where multiple problems exist in single locations. Scan each clause thoroughly - don't stop after finding the first issue.

**BIDIRECTIONAL SCANNING:** Always check BOTH English→BM AND BM→English for missing content. Many discrepancies involve content present in one version but missing in the other. **Pay EXTRA attention to missing translations in the BM version - this is a common issue where English descriptive words are frequently omitted in Bahasa Malaysia translations.**

**TABLE CONTENT FOCUS:** For tables, compare only the content, headers, and data within the tables - do not flag differences in layout, formatting, or visual structure. Focus solely on textual content, amounts, and data accuracy.

**WORD-LEVEL PRECISION REQUIRED:** Flag ANY missing word, even if the overall sentence meaning is clear. Legal documents require perfect word-for-word accuracy, not just conceptual equivalence. A missing adjective, adverb, or descriptive word must be flagged regardless of whether the sentence still makes sense.

**ASYMMETRIC TRANSLATION DETECTION:** Also flag when one version has MORE qualifying words than the other. Both under-translation and over-specification must be detected.

Completeness is more important than brevity.
DO NOT summarize the output even if the output is very long. Provide the full detailed analysis as specified.

---

Here are the two documents:

**ENGLISH_VERSION:**
{doc1}

**BAHASA_MALAYSIA_VERSION:**
{doc2}"""

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "human",
            instruction
        ),
    ]
)

# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
load_dotenv()

reasoning = {
    # "effort": "high",  # 'low', 'medium', or 'high'
}
model = ChatOpenAI(model="gpt-4.1", use_responses_api=True, model_kwargs={"reasoning": reasoning})
chain = prompt | model | StrOutputParser()
result = chain.invoke({"doc1": doc1_content, "doc2": doc2_content})

# %%
print(result)
# Out:
# ```json
# {
#   "total": 56,
#   "flags": [
#     {
#       "location": "Document Title and Section Header",
#       "doc1": {
#         "content": "<span style=\"color: red\">HONG LEONG WISE CREDIT CARD TERMS AND CONDITIONS (Versi Bahasa Malaysia)</span> Last updated 10 December 2024"
#       },
#       "doc2": {
#         "content": "<span style=\"color: red\">TERMA DAN SYARAT KAD KREDIT WISE HONG LEONG (English Version)</span> Dikemas Kini 10 Disember 2024"
#       },
#       "discrepancies": [
#         "1. Language/label mismatch: English version refers to '(Versi Bahasa Malaysia)' while BM version refers to '(English Version)'.",
#         "2. English has 'Last updated 10 December 2024'; BM has 'Dikemas Kini 10 Disember 2024'.",
#         "3. Language code switch: headers in English at top of English document but BM at top of BM document."
#       ],
#       "explanation": "Document titles/section headers do not fully correspond. Language codes/indicators are swapped. Date format and wording also differ between versions."
#     },
#     {
#       "location": "Introduction/Opening Paragraph",
#       "doc1": {
#         "content": "These HLB WISE Credit Card (' WISE Card ') Terms and Conditions (' T&Cs ') are to be read together with the Hong Leong Bank Berhad's (\" HLB \") Cardholder Agreement (\" the Agreement \"). Save and except for the variations set out below, all the terms and conditions of the Agreement shall apply. In the event of any discrepancy or inconsistency between the terms and conditions of the Agreement and these T&Cs, these T&Cs shall prevail in so far as they are applicable to the WISE Card. By accepting the WISE Card, the Cardholder  (as  defined  herein)  agrees  to  be  bound  by  these  T&Cs  and  terms  and  conditions  of  the Agreement."
#       },
#       "doc2": {
#         "content": "Terma dan Syarat (' T&S ') Kad Kredit WISE HLB (' Kad WISE ') hendaklah dibaca bersama dengan Perjanjian Pemegang Kad (' Perjanjian ') Hong Leong Bank Berhad (\" HLB \"). Selain daripada variasi yang dinyatakan di bawah, semua terma dan syarat Perjanjian hendaklah diterima pakai. Sekiranya terdapat percanggahan atau ketidakselarasan antara terma dan syarat Perjanjian dengan terma dan syarat T&S ini  T&S ini ini hendaklah diutamakan setakat mana yang berkenaan dengan Kad WISE. Dengan menerima Kad WISE, Pemegang Kad bersetuju untuk terikat dengan T&S ini dan Perjanjian."
#       },
#       "discrepancies": [
#         "1. The phrase 'These HLB WISE Credit Card (' WISE Card ') Terms and Conditions (' T&Cs ') are to be read together with' is translated as 'Terma dan Syarat (' T&S ') Kad Kredit WISE HLB (' Kad WISE ') hendaklah dibaca bersama dengan', omitting 'these' and reversing the order.",
#         "2. English 'Cardholder Agreement (\" the Agreement \")' translated as 'Perjanjian Pemegang Kad (' Perjanjian ')', minor switch in order and omission of 'Cardholder' in quotes in BM.",
#         "3. English 'Save and except for the variations set out below, all the terms and conditions of the Agreement shall apply.' translated as 'Selain daripada variasi yang dinyatakan di bawah, semua terma dan syarat Perjanjian hendaklah diterima pakai.'; the phrase 'shall apply' in English is more direct, while BM's 'hendaklah diterima pakai' means 'shall be accepted and applied', a mild interpretation difference.",
#         "4. English 'In the event of any discrepancy or inconsistency between the terms and conditions of the Agreement and these T&Cs, these T&Cs shall prevail in so far as they are applicable to the WISE Card.' BM omits 'in so far as they are applicable to the WISE Card' (BM: 'setakat mana yang berkenaan dengan Kad WISE'), which corresponds, but the BM placement at the end changes clarity.",
#         "5. English 'Cardholder (as defined herein)' is missing from BM version.",
#         "6. BM 'T&S ini ini' is a repetition error.",
#         "7. English 'and terms and conditions of the Agreement' is simply 'dan Perjanjian' in BM, omitting explicit reference to 'terma dan syarat Perjanjian'.",
#         "8. English 'By accepting the WISE Card, the Cardholder (as defined herein) agrees to be bound by these T&Cs and terms and conditions of the Agreement.' BM omits the clarification '(as defined herein)'."
#       ],
#       "explanation": "Numerous minor terminology discrepancies, a repetition error in BM, missing explanations in BM (e.g. 'as defined herein'), as well as word order swaps, add up to several content, clarity, and structure variations."
#     },
#     {
#       "location": "Section 1(a) Programme Eligibility - Opening Clause",
#       "doc1": {
#         "content": "- (a) Principal Cardholders of the WISE Card (' Cardholders \") will be awarded with cashback of up to 15% (' Cashback '), subject to the following:"
#       },
#       "doc2": {
#         "content": "- (a)  Pemegang  Kad  Utama  WISE  (' Pemegang  Kad  Utama ')  akan  menerima  pulangan  tunai sehingga 15% (' Pulangan Tunai '), tertakluk kepada yang berikut:"
#       },
#       "discrepancies": [
#         "1. English 'Principal Cardholders of the WISE Card (' Cardholders \")' is explicitly describing both Principal Cardholders and the 'WISE Card', while BM is 'Pemegang Kad Utama WISE (' Pemegang Kad Utama '), omitting a general 'Cardholders' definition.",
#         "2. English 'will be awarded with cashback of up to 15%' is 'akan menerima pulangan tunai sehingga 15%' in BM. The word 'up to' is correctly 'sehingga', but English's 'awarded with' (passive) is 'akan menerima' (active).",
#         "3. English uses double 'quotes' after 'Cardholders', suggesting a typo.",
#         "4. Word 'cashback' is not translated literally; BM uses 'pulangan tunai'.",
#         "5. English puts 'Cashback' in brackets and quotation marks; BM uses single quotes on 'Pulangan Tunai'.",
#         "6. BM omits 'of the WISE Card', and both versions lack symmetry in reference labels (Cardholders/Pemegang Kad Utama)."
#       ],
#       "explanation": "Discrepancies largely center on missing/added descriptors, word order, definition phrasing, and possible typographical issues."
#     },
#     {
#       "location": "Section 1(a)(i)",
#       "doc1": {
#         "content": "- (i) a minimum spend of Ringgit Malaysia One Thousand (RM1,000) on the Eligible Retail Transactions (as defined under Clause 3(a) herein) in each calendar month where the minimum spend is calculated after taking into account all reversals (if any);"
#       },
#       "doc2": {
#         "content": "- (i) perbelanjaan minimum Ringgit Malaysia Satu Ribu (RM1,000) dari Transaksi Runcit Layak (seperti ditakrif dalam Klausa 3(a) disini) pada setiap bulan calendar di mana perbelanjaan minimum dikira selepas mengambil kira semua pembalikan (jika ada);"
#       },
#       "discrepancies": [
#         "1. English 'calendar month' is 'bulan calendar' in BM, which should be 'bulan kalendar' (spelling error and inconsistent language mixing).",
#         "2. 'from Eligible Retail Transactions' is translated as 'dari Transaksi Runcit Layak', direct translation, but English says 'on the Eligible Retail Transactions', this is not a major clarity loss but word choice differs.",
#         "3. English 'where the minimum spend is calculated after taking into account all reversals (if any)' is 'di mana perbelanjaan minimum dikira selepas mengambil kira semua pembalikan (jika ada)'; consistent meaning, but English used 'minimum spend', BM repeats 'perbelanjaan minimum', and wording is slightly different.",
#         "4. English: 'as defined under Clause 3(a) herein', BM: 'seperti ditakrif dalam Klausa 3(a) disini' (possible spelling/localization, and 'di sini' should be separated)."
#       ],
#       "explanation": "Punctuation and spelling inconsistencies, language mixing, word order, and minor literal translation issues."
#     },
#     {
#       "location": "Section 1(a)(ii)",
#       "doc1": {
#         "content": "- (ii) such minimum spend of Ringgit Malaysia One Thousand (RM1,000) on the Eligible Retail Transactions are posted in the same calendar month; and"
#       },
#       "doc2": {
#         "content": "- (ii) perbelanjaan  minimum  Ringgit  Malaysia  Satu  Ribu  (RM1,000)  tersebut  atas  Transaksi Runcit Layak tercatat dalam bulan kalendar yang sama; dan"
#       },
#       "discrepancies": [
#         "1. 'are posted' is more clearly 'tercatat' as a verb in BM; ok, but English's passive is not matched.",
#         "2. 'on the Eligible Retail Transactions' is 'atas Transaksi Runcit Layak' (literal), omitting preposition difference.",
#         "3. 'calendar month' is correctly 'bulan kalendar' here, showing inconsistency with previous 'bulan calendar'.",
#         "4. No major loss of meaning, but missing considerations for word-for-word passive voice."
#       ],
#       "explanation": "Slight formality difference, but mostly accurate. Only minor differences in voice and preposition usage."
#     },
#     {
#       "location": "Section 1(a)(iii)",
#       "doc1": {
#         "content": "- (iii) such  Eligible  Retail  Transactions  fall  under  the  permitted  categories  (i.e.  Spend Category and Eligible Merchant Category Codes (MCC), Merchants and/or Transactions) as listed in Table 1 below; or such other conditions as may be notified by HLB from time to time."
#       },
#       "doc2": {
#         "content": "- (iii)  Transaksi  Runcit  Layak  tersebut  termasuk  dalam  kategori  (iaitu  Kod  Kategori  Peniaga (MCC), Peniaga dan/atau Transaksi seperti tersenarai dalam Klausa 1(b) di bawah, atau apa-apa syarat lain yang dimaklumkan oleh HLB dari semasa ke semasa."
#       },
#       "discrepancies": [
#         "1. 'permitted categories (i.e. Spend Category and Eligible Merchant Category Codes (MCC), Merchants and/or Transactions)' is simplified to 'kategori (iaitu Kod Kategori Peniaga (MCC), Peniaga dan/atau Transaksi' — omits 'Spend Category' and 'Eligible' descriptors.",
#         "2. English points to 'Table 1 below'; BM says 'Klausa 1(b) di bawah', referring to a clause not a table (table/section reference inconsistency).",
#         "3. Word-for-word, BM version misses 'permitted' and 'eligible' adjectives.",
#         "4. In English, the clause ends with '; or such other conditions as may be notified by HLB from time to time.', BM puts 'atau apa-apa syarat lain yang dimaklumkan oleh HLB dari semasa ke semasa.' inside the clause with slightly different punctuation/scoping.",
#         "5. English syntax has a semicolon before 'or', BM uses a comma."
#       ],
#       "explanation": "BM omits 'Spend Category'/'Eligible' descriptors, refers to a section rather than Table 1, and there are formatting differences."
#     },
#     {
#       "location": "Section 1(b) Cashback Reference",
#       "doc1": {
#         "content": "- (b) The earning of the respective Cashback is stipulated in Table 1 below:"
#       },
#       "doc2": {
#         "content": "- (b)  Perolehan Pulangan Tunai masing - masing dipaparkan dalam Jadual 1 di bawah:"
#       },
#       "discrepancies": [
#         "1. 'is stipulated' is translated as 'dipaparkan', which is 'displayed/shown', omitting the legal formality of 'stipulated/determined' in English.",
#         "2. Word order of 'masing - masing' is split by spaces, should be 'masing-masing' (spelling/formatting error).",
#         "3. English: 'Table 1', BM: 'Jadual 1' (consistent, but no explicit note flag needed for term change)."
#       ],
#       "explanation": "BM uses weaker terminology ('displayed' vs 'stipulated') and contains a hyphenation/spacing error."
#     },
#     {
#       "location": "Table 1 - Row Headers",
#       "doc1": {
#         "content": "| Minimum Spend/ month (Posted Transaction)   | Spend category         | Eligible Merchant Category Codes (MCC), Merchants and/or Transactions | ..."
#       },
#       "doc2": {
#         "content": "| Perbelanjaan Minimum / Bulanan (Transaksi yang dipos)   | Kategori Perbelanjaan       | Kad Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak | ..."
#       },
#       "discrepancies": [
#         "1. 'Spend category' (English) translated as 'Kategori Perbelanjaan' (BM) — acceptable, no explicit omission.",
#         "2. English: 'Eligible Merchant Category Codes (MCC), Merchants and/or Transactions'; BM: 'Kad Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak'. BM adds 'Yang Layak', not in English.",
#         "3. English: 'Minimum Spend/ month (Posted Transaction)' = BM: 'Perbelanjaan Minimum / Bulanan (Transaksi yang dipos)'. BM uses 'yang dipos', not 'posted' as in English; word order varies."
#       ],
#       "explanation": "General translation differences and word additions without meaning drift, but specific words like 'Eligible' appear in BM where not in English version."
#     },
#     {
#       "location": "Table 1 - Dining Category, English",
#       "doc1": {
#         "content": "|                                             | Dining                 | • MCC: 5811/5812/5814 - All dining outlets. | ..."
#       },
#       "doc2": {
#         "content": "| RM1,000                                                 | Jamu Selera                 | • MCC: 5811/5812/5814 - Semua kedai makan | ..."
#       },
#       "discrepancies": [
#         "1. 'Dining' is 'Jamu Selera' in BM instead of a direct translation like 'Makan'; could cause confusion/inconsistency.",
#         "2. English 'All dining outlets' translated as 'Semua kedai makan'; the precise term 'outlets' is not explicitly translated.",
#         "3. BM omits the English row indicating an empty spend amount for Dining; assigns RM1,000 under 'Dining', inconsistent with placement in English table.",
#         "4. Placement of columns/row headers differs; 'Spend' is at left in English and directly with category in BM."
#       ],
#       "explanation": "The main issue is the translation of 'Dining' (not literal, leading to possible confusion with regular meals), and Table row structure/placement is not perfectly mirrored."
#     },
#     {
#       "location": "Table 1 - Row: Groceries & Essentials/ Barangan Keperluan & Runcit",
#       "doc1": {
#         "content": "| RM1,000                                     | Groceries & Essentials | • MCC: 5411 - All grocery stores including Giant, Cold Storage, Jaya Grocer, Mercato, etc. • MCC: 5912 - All drug stores and pharmacies including Guardian, Watsons, Caring Pharmacy, etc. • Selected convenience stores - MyNews and 7- Eleven. | ..."
#       },
#       "doc2": {
#         "content": "| RM1,000                                                 | Barangan Keperluan & Runcit | • MCC: 5411 - Semua kedai runcit termasuk Giant, Cold Storage, Jaya Grocer, Mercato, dan lain-lain. • MCC: 5912 - Semua kedai ubat dan farmasi termasuk Guardian, Watsons, Caring Pharmacy dan lain-lain • Kedai Serbaneka yang terpilih - MyNews and 7Eleven | ..."
#       },
#       "discrepancies": [
#         "1. 'Groceries & Essentials' in English is 'Barangan Keperluan & Runcit' in BM (word order reversed). Should be 'Barangan Runcit & Keperluan'.",
#         "2. 'All grocery stores' (English) is 'Semua kedai runcit' (BM). 'Grocery' (makanan) is different from 'kedai runcit' (which can also mean sundry shop); slight meaning shift.",
#         "3. 'Drug stores and pharmacies' becomes 'kedai ubat dan farmasi', which is accurate, but 'drug stores' (could be for over-the-counter) and 'farmasi' specifics are not mirrored.",
#         "4. 'Including Guardian, Watsons, Caring Pharmacy, etc.' becomes 'termasuk ... dan lain-lain.'; the 'etc.' is 'dan lain-lain', but BM omits comma before 'dan lain-lain'.",
#         "5. English 'Selected convenience stores - MyNews and 7- Eleven' translated as 'Kedai Serbaneka yang terpilih - MyNews and 7Eleven'; the dash '7- Eleven' has a space in English, not BM.",
#         "6. BM omits 'Selected', or at least doesn't clarify which convenience stores (as per the English phrase)."
#       ],
#       "explanation": "Word order, translation accuracy for 'Grocery', missing dashes, and 'Selected' not fully translated make for several discrepancies."
#     },
#     {
#       "location": "Table 1 - Petrol Row",
#       "doc1": {
#         "content": "| RM1,000                                     | Petrol                 | • MCC: 5542 | Enjoy 0.5% | Enjoy 10% | RM15 |"
#       },
#       "doc2": {
#         "content": "|                                                   | Petrol                      | • MCC: 5542 - Dispenser Bahan Bakar Automatik (layan diri) di semua stesen minyak | Nikmati 0.5% Pulangan Tunai | Nikmati 10% PulanganTunai | RM15 |"
#       },
#       "discrepancies": [
#         "1. English has only 'MCC: 5542'; BM expands this to 'MCC: 5542 - Dispenser Bahan Bakar Automatik (layan diri) di semua stesen minyak' — added explanatory detail in BM not appearing in English.",
#         "2. 'Enjoy 0.5%' and 'Enjoy 10%' in English are 'Nikmati 0.5% Pulangan Tunai' and 'Nikmati 10% PulanganTunai' in BM; the double capital 'Tunai' is run together in BM without a space.",
#         "3. English has 'Petrol' twice (as separate rows with different descriptions); BM merges the information."
#       ],
#       "explanation": "BM adds a detailed description of petrol transaction type not in English and has a run-on word in 'PulanganTunai'. English version is less specific about transaction type."
#     },
#     {
#       "location": "Table 1 - Online Spend row / Perbelanjaan Dalam Talian",
#       "doc1": {
#         "content": "|                                             | Online Spend                | • Lazada • Shopee • Grab • Foodpanda • Touch 'n Go • MYEG • Spotify • Netflix • Apple Music Note: Applicable to eWallet reload and food delivery transactions for the above listed merchant only | ... |"
#       },
#       "doc2": {
#         "content": "|                                                         | Perbelanjaan Dalam Talian   | • Lazada • Shopee • Grab • Foodpanda • Touch 'n Go • MYEG • Spotify | ... |"
#       },
#       "discrepancies": [
#         "1. English version includes 'Spotify • Netflix • Apple Music Note: Applicable to eWallet reload and food delivery transactions for the above listed merchant only' in this row; BM moves 'Netflix • Apple Music Nota: Termasuk tambah nilai e-wallet dan servis penghantaran makanan untuk peniaga yang disenaraikan di atas sahaja' to next row (broken table input).",
#         "2. In BM, 'Note' is translated as 'Nota', but placed at the start of the row and not at the end.",
#         "3. BM omits 'Applicable to eWallet reload and food delivery transactions for the above listed merchant only' from this row; appears in patchwork fashion in second row.",
#         "4. Spotify • Netflix • Apple Music do not all appear together or in same order in BM.",
#         "5. Structural/formatting misalignment between table rows."
#       ],
#       "explanation": "BM separates merchant names and descriptive notes awkwardly across table rows, rather than grouping as in English."
#     },
#     {
#       "location": "Table 1 - Others (including overseas)/Lain-lain",
#       "doc1": {
#         "content": "|                                             | Others (including overseas) | • Any Other Eligible MCC, Merchants and/or Transactions. | Enjoy 0.20% Cashback | Enjoy 0.20% Cashback | Unlimited |"
#       },
#       "doc2": {
#         "content": "|               | Lain-lain (Termasuk transaksi luar negara) | • Semua Kod Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak Yang Lain | Nikmati 0.20% Pulangan Tunai | Tiada Had |"
#       },
#       "discrepancies": [
#         "1. BM: 'Lain-lain (Termasuk transaksi luar negara)' adds direct translation; order of the phrase is slightly altered.",
#         "2. English: 'Any Other Eligible MCC, Merchants and/or Transactions.' BM: 'Semua Kod Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak Yang Lain,' a slightly different shape with 'Yang Lain' at the end — word order varies.",
#         "3. 'Enjoy 0.20% Cashback' x2 in English (Weekdays, Weekends); BM collapses to a single value.",
#         "4. 'Unlimited' in English is 'Tiada Had' in BM.",
#         "5. Cashback value column is omitted in BM."
#       ],
#       "explanation": "The main discrepancy is in the word ordering and presentation of the cashback value for weekdays/weekends (single in BM). Also, 'Unlimited' is translated idiomatically."
#     },
#     {
#       "location": "Table 1 - Below Minimum Spend row",
#       "doc1": {
#         "content": "| Below RM1,000                               | All                         | • All Eligible MCC, Merchants and/or Transactions. | Enjoy 0.20% Cashback | Enjoy 0.20% Cashback | RM2 |"
#       },
#       "doc2": {
#         "content": "| Bawah RM1,000 | Semua | • Semua Kod Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak Yang Lain | Nikmati 0.20% Pulangan Tunai | RM2 |"
#       },
#       "discrepancies": [
#         "1. English header is 'All', BM is 'Semua'.",
#         "2. The phrase 'Eligible MCC, Merchants and/or Transactions.' in English is 'Kod Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak Yang Lain' in BM; the term 'Eligible' is inserted and 'Yang Lain' placed at the end.",
#         "3. 'Enjoy 0.20% Cashback' x2 in English is only mentioned once in BM.",
#         "4. Table row structure is collapsed in BM (missing one column compared to English)."
#       ],
#       "explanation": "Word order, row structure, and phrase translations create inconsistencies here."
#     },
#     {
#       "location": "Section 1(c) Calculation of Cashback",
#       "doc1": {
#         "content": "- (c) The  entitlement  of  Cashback  is  calculated  based  on  posted  transaction  in  each  calendar month. Cardholders who do not meet the monthly minimum spend requirement of Ringgit Malaysia One Thousand (RM1,000) as stated under Clauses 1(a) (i) and (ii) above or in the event the posted amount is below Ringgit Malaysia One Thousand (RM1,000) in that particular calendar month, such Cardholders will not be entitled to the up to 1% (Weekdays) or 15% (Weekends)  Cashback  in  that  particular  month  as  stated  in  Table  1.  However,  such Cardholders will still be entitled to 0.20% Cashback for all their Eligible Retail Transactions (i.e. below Ringgit Malaysia One Thousand (RM1,000)) in that particular month provided that the accumulated Cashback amount is not less than Ringgit Malaysia One (RM1)."
#       },
#       "doc2": {
#         "content": "- (c)  Kelayakan menerima Pulangan Tunai dikira berdasarkan transaksi yang tercatat pada setiap bulan.  Pemegang Kad yang tidak memenuhi perbelanjaan minimum Ringgit Malaysia  Satu Ribu (RM1,000) sebulan seperti dinyatakan dalam Klausa 1(a)(i) dan (ii) atau sekiranya amaun transaksi yang tercatat itu adalah di bawah Ringgit Malaysia Satu Ribu (RM1,000) pada bulan kalendar  berkenaan,  Pemegang  Kad  tersebut  tidak  akan  layak  menerima  Pulangan  Tunai sehingga 1% (hari bekerja) atau 15% (hujung minggu) pada bulan berkenaan. Akan tetapi, Pemegang Kad tersebut tetap layak menerima Pulangan Tunai 0.2% bagi Transaksi Runcit Layak (i.e. bawah Ringgit Malaysia Seribu (RM1,000)) yang dibuat dalam bulan berkenaan dengan syarat jumlah pulangan tunai terkumpul tidak kurang daripada Ringgit Malaysia Satu (RM1)."
#       },
#       "discrepancies": [
#         "1. English: 'entitlement of Cashback is calculated based on posted transaction in each calendar month'; BM: 'dikira berdasarkan transaksi yang tercatat pada setiap bulan'—'calendar' omitted.",
#         "2. English: 'such Cardholders will not be entitled to the up to 1% (Weekdays) or 15% (Weekends) Cashback...' BM: 'tidak akan layak menerima Pulangan Tunai sehingga 1% (hari bekerja) atau 15% (hujung minggu)...'; 'Pulangan Tunai' used generically, with percentages at different places.",
#         "3. BM omits explicit 'as stated in Table 1' found in English.",
#         "4. BM uses 'sebulan seperti dinyatakan dalam' which is similar to English 'monthly', but the repetition is not mirrored.",
#         "5. 'Eligible Retail Transactions (i.e. below Ringgit Malaysia One Thousand (RM1,000))' translated as 'Transaksi Runcit Layak (i.e. bawah Ringgit Malaysia Seribu (RM1,000))' missing explicit English 'for all their'.",
#         "6. Phrase 'in that particular month provided that the accumulated Cashback amount is not less than Ringgit Malaysia One (RM1)' is faithfully translated but omits 'that particular month' after 'provided that ...'."
#       ],
#       "explanation": "BM omits 'calendar', 'as stated in Table 1', and alters word order, with small translation and contextual word/phrase losses."
#     },
#     {
#       "location": "Table 2 - Transaction Type: Barangan Runcit & Keperluan",
#       "doc1": {
#         "content": "| Groceries & Essentials | RM150 | 13-Jul-24 | Saturday | 14-Jul-24 | Sunday |"
#       },
#       "doc2": {
#         "content": "| Barangan Runcit & Keperluan | RM150 | 13-Jul-24 | Sabtu | 14-Jul-24 | Ahad |"
#       },
#       "discrepancies": [
#         "1. English 'Groceries & Essentials' is reversed as 'Barangan Runcit & Keperluan' in BM (not matching 'Barangan Keperluan & Runcit' as in earlier BM table).",
#         "2. BM translation not standardized within document (earlier 'Barangan Keperluan & Runcit')."
#       ],
#       "explanation": "Internal BM inconsistency in translation for this spend category."
#     },
#     {
#       "location": "Table 2 - Transaction Type: Online Spend",
#       "doc1": {
#         "content": "| Online Spend | RM1,520 | 11-Jul-24 | Thursday | 12-Jul-24 | Friday |"
#       },
#       "doc2": {
#         "content": "| Perbelanjaan Dalam Talian | RM1,520 | 11-Jul-24 | Khamis | 12-Jul-24 | Jumaat |"
#       },
#       "discrepancies": [
#         "1. English 'Online Spend' is 'Perbelanjaan Dalam Talian' in BM; this translation is consistent, but not literal ('Perbelanjaan Atas Talian' is often used)."
#       ],
#       "explanation": "Slightly different but commonly accepted word-for-word translation."
#     },
#     {
#       "location": "Table 2 - Transaction Type: Dining",
#       "doc1": {
#         "content": "| Dining | RM 135 | 13-Jul-24 | Saturday | 14-Jul-24 | Sunday |"
#       },
#       "doc2": {
#         "content": "| Jamu Selera | RM135 | 13-Jul-24 | Sabtu | 14-Jul-24 | Ahad |"
#       },
#       "discrepancies": [
#         "1. The translation 'Dining' as 'Jamu Selera' is inconsistent with direct translation ('Makan' or 'Santapan').",
#         "2. Inconsistency with international standard translation."
#       ],
#       "explanation": "Repetitive issue of 'Jamu Selera' used for 'Dining', which is not standard."
#     },
#     {
#       "location": "Table 2 - Transaction Type: Others",
#       "doc1": {
#         "content": "| Others | RM20 | 23-Jul-24 | Tuesday | 24-Jul-24 | Wednesday |"
#       },
#       "doc2": {
#         "content": "| Lain | RM20 | 23-Jul-24 | Selasa | 24-Jul-24 | Rabu |"
#       },
#       "discrepancies": [
#         "1. 'Others' becomes 'Lain' in BM, but elsewhere 'Lain-lain' is used (BM internal inconsistency)."
#       ],
#       "explanation": "'Others' should be consistently translated as 'Lain-lain', not sometimes 'Lain'."
#     },
#     {
#       "location": "Table 2 - Transaction Type: Online Spend (Reversal)",
#       "doc1": {
#         "content": "| Online Spend (Reversal) | RM(20) | 20-Jul-24 | Saturday | 21-Jul-24 | Sunday |"
#       },
#       "doc2": {
#         "content": "| Perbelanjaan Dalam Talian (Pembalikan) | RM(20) | 20-Jul-24 | Sabtu | 21-Jul-24 | Ahad |"
#       },
#       "discrepancies": [
#         "1. 'Reversal' is translated as 'Pembalikan'; direct match.",
#         "2. English 'Online Spend (Reversal)' is 'Perbelanjaan Dalam Talian (Pembalikan)'; translation is correct, but not literal."
#       ],
#       "explanation": "No major loss of meaning, only literal translation deviation."
#     },
#     {
#       "location": "Q&A: Minimum Spend Calculation",
#       "doc1": {
#         "content": "Q: Does the Cardholder meet the minimum spend of RM1,000? A: Yes, the total posted transactions amount for July 2024 that will form part of the minimum spend... (which  consists  of  Ringgit  Malaysia  Four  Hundred  (RM400)  from  JomPay, Ringgit Malaysia One Hundred Fifty (RM150) from Groceries & Essentials, Ringgit Malaysia One Thousand Five Hundred (RM1,500) from Online Spend (after the reversal of RM20), Ringgit Malaysia One Hundred Thirty-Five (RM135) from Dining, Ringgit Malaysia One Hundred Fifty (RM150) from Petrol and Ringgit Malaysia Twenty (RM20) from Others)."
#       },
#       "doc2": {
#         "content": "Q: Adakah Pemegang Kad memenuhi perbelanjaan minimum RM1000? A: Ya, jumlah  transaksi tercatat pada Julai 2024 yang dikira sebagai perbelanjaan minimum Ringgit  Malaysia  Satu  Ribu  (RM1,000) adalah Ringgit Malaysia  Dua Ribu Tiga Ratus Lima Puluh  Lima  (RM2,355)  (yang  terdiri  daripada  Ringgit  Malaysia  Empat  Ratus  (RM400)  dari JomPAY, Ringgit Malaysia Seratus Lima Puluh (RM150) dari Barangan Runcit & Keperluan, Ringgit Malaysia Lapan Puluh (RM1,500) dari Perbelanjaan Dalam Talian (selepas tolak RM20 daripada Pembalikan), Ringgit Malaysia Seratus Tiga Puluh Lima (RM135) dari Jamu Selera, Ringgit Malaysia Seratus Lima Puluh (RM150) dari Petrol  dan Ringgit Malaysia Dua Puluh (RM20) dari Kategori Lain)"
#       },
#       "discrepancies": [
#         "1. BM: 'Ringgit Malaysia Lapan Puluh (RM1,500)' is an error; should be 'Ringgit Malaysia Seribu Lima Ratus (RM1,500)'.",
#         "2. English: 'from Groceries & Essentials'; BM: 'dari Barangan Runcit & Keperluan' (see previous note re: inconsistent translation order).",
#         "3. English: 'from Dining'; BM: 'dari Jamu Selera' (translation style issue, see above).",
#         "4. English: 'from Others'; BM: 'dari Kategori Lain' — category not always described as 'Kategori' in other tables.",
#         "5. BM: Internal numeric word/number mismatch ('Lapan Puluh (RM1,500)')."
#       ],
#       "explanation": "Main issue is spelling/amount error in BM ('Eighty' for RM1,500), inconsistent translation of categories, and some inconsistencies in description."
#     },
#     {
#       "location": "Q&A: Eligibility of JomPAY cashback",
#       "doc1": {
#         "content": "Q: How much Cashback did the Cardholder earn for the JomPAY transaction performed on 1 July 2024? A: Ringgit Malaysia Zero (RM0) as transaction(s) for JomPAY are not eligible for the Cashback. This is provided under Clause 3(a) below."
#       },
#       "doc2": {
#         "content": "Q: Berapa Pulangan Tunai yang diperoleh Pemegang Kad untuk transaksi JomPAY yang dilakukan pada 1 Julai 2024? A:  Ringgit  Malaysia  Sifar  (RM0)  kerana  transaksi  untuk  JomPAY  tidak  layak  mendapat Pulangan Tunai. Sila merujuk kepada Klausa 3(a) di bawah untuk maklumat lanjut."
#       },
#       "discrepancies": [
#         "1. English: 'This is provided under Clause 3(a) below.' BM: 'Sila merujuk kepada Klausa 3(a) di bawah untuk maklumat lanjut.' — English direct reference, BM adds 'untuk maklumat lanjut' as extra info (asymmetrical translation)."
#       ],
#       "explanation": "BM version adds extra phrase 'untuk maklumat lanjut' not present in English."
#     },
#     {
#       "location": "Q&A: Petrol cashback for 31 August transaction",
#       "doc1": {
#         "content": "Q: How much Cashback did the Cardholder earn in July for the transaction for Petrol on 31 August 2024? A: The Ringgit Malaysia One Hundred (RM100) Petrol transaction will not form part of the Cashback for  July  2024  (i.e.  Ringgit  Malaysia  Zero  (RM0)  Cashback)  as  it  is  only  posted  in  August  2024. However,  the  Ringgit  Malaysia  One  Hundred  (RM100)  Petrol  transaction  will  form  part  of  the Cashback for August 2024 (up to 15% Cashback if the Cardholder meets the Ringgit Malaysia One Thousand (RM1,000) minimum spend requirement in August or 0.20% Cashback otherwise (i.e. minimum spend amount below Ringgit Malaysia One Thousand (RM1000))."
#       },
#       "doc2": {
#         "content": "Q: Berapakah Pulangan Tunai yang diperoleh Pemegang Kad pada bulan Julai untuk transaksi Petrol pada 31 Ogos 2024? A:  Transaksi  Petrol  Ringgit  Malaysia  Seratus  (RM100)  tidak  akan  dianggap  sebahagian daripada pulangan tunai untuk Julai 2024 (iaitu pulangan tunai Ringgit Malaysia Sifar (RM0)) kerana transaksi tersebut hanya tercatat pada Ogos 2024. Walau bagaimanapun, transaksi Petrol Ringgit Malaysia Seratus (RM100) akan menjadi sebahagian daripada pulangan tunai untuk  Ogos  2024  (pulangan  tunai  15%  jika  Pemegang  kad  memenuhi  syarat  perbelanjaan minimum Ringgit Malaysia Satu Ribu (RM1,000) pada bulan Ogos; ataupun pulangan tunai 0.2%  sekiranya  perbelanjaan  minimum  tidak  tercapai.  i.e.  bawah  Ringgit  Malaysia  Seribu (RM1,000))."
#       },
#       "discrepancies": [
#         "1. English: 'as it is only posted in August 2024.' BM: 'kerana transaksi tersebut hanya tercatat pada Ogos 2024.' ('posted' vs 'tercatat').",
#         "2. English: 'up to 15% Cashback if the Cardholder meets... or 0.20% Cashback otherwise.' BM: 'pulangan tunai 15% jika Pemegang kad memenuhi syarat...; ataupun pulangan tunai 0.2% sekiranya...'. BM omits 'up to' (sehingga) for 'pulangan tunai 15%'.",
#         "3. English: 'minimum spend amount below Ringgit Malaysia One Thousand (RM1000)'. BM: 'i.e. bawah Ringgit Malaysia Seribu (RM1,000)).'",
#         "4. BM omits the word 'otherwise' (otherwise would be 'jika tidak')."
#       ],
#       "explanation": "BM misses some qualifiers and omits 'up to', changes 'posted' to 'tercatat', and reduces formality in end condition ('otherwise')."
#     },
#     {
#       "location": "Q&A: Total Cashback Earned in July",
#       "doc1": {
#         "content": "Q: What is the total amount of Cashback the Cardholder has earned for the month of  July 2024? A: Ringgit Malaysia Sixty-Five (RM65). Please refer to Table 3 below for the illustration of Cashback calculation for the month of July 2024."
#       },
#       "doc2": {
#         "content": "A: Ringgit Malaysia  Enam Puluh Lima (RM65). Sila rujuk Jadual 3 di bawah untuk ilustrasi pengiraan Pulangan Tunai bagi bulan Julai 2024."
#       },
#       "discrepancies": [
#         "1. English explicitly labels 'Q:'; BM omits explicit question.",
#         "2. English: 'illustration of Cashback calculation'; BM: 'ilustrasi pengiraan Pulangan Tunai' — 'calculation of Cashback' translated as 'pengiraan Pulangan Tunai' ('of' translation is literal)."
#       ],
#       "explanation": "BM omits explicit 'Q' and literal structure varies slightly."
#     },
#     {
#       "location": "Table 3 - Dining Row",
#       "doc1": {
#         "content": "| Dining | 135 | 13-Jul (Weekend) | 15% | 20 | 20 |"
#       },
#       "doc2": {
#         "content": "| Jamu Selera | 200 | 13-Jul (Hujung Minggu) | 15% | 20 | 20 |"
#       },
#       "discrepancies": [
#         "1. BM value is '200', but in English it is '135' — inconsistent transaction value.",
#         "2. 'Weekend' is 'Hujung Minggu' in BM (correct translation).",
#         "3. 'Dining' is 'Jamu Selera' (already flagged issue of translation consistency)."
#       ],
#       "explanation": "Amount discrepancy: RM135 in English, RM200 in BM; repeated translation style issue."
#     },
#     {
#       "location": "Table 3 - Groceries & Essentials Row",
#       "doc1": {
#         "content": "| Groceries & Essentials | 150 | 13-Jul (Weekend) | 10% | 15 | 15 |"
#       },
#       "doc2": {
#         "content": "| Barangan Runcit & Keperluan | 450 | 13-Jul (Hujung Minggu) | 10% | 15 | 15 |"
#       },
#       "discrepancies": [
#         "1. Amount is '150' in English, '450' in BM.",
#         "2. Category name is reversed, as in previous flags."
#       ],
#       "explanation": "Discrepancy in transaction amount and translation order inconsistency."
#     },
#     {
#       "location": "Table 3 - Total Amount Row",
#       "doc1": {
#         "content": "| Total Amount of Cashback (RM) | 65 Note: The Cashback awarded will be rounded (up or down) to the settlement of the nearest Ringgit Malaysia | ..."
#       },
#       "doc2": {
#         "content": "Jumalah Pulangan 65 Tunai (RM) Nota: Pulangan tunai yang diberikan akan dibundarkan (atas atau bawah) kepada Ringgit Malaysia ('RM') yang terdekat."
#       },
#       "discrepancies": [
#         "1. BM has 'Jumalah', which is a spelling error; correct word is 'Jumlah'.",
#         "2. Word order: 'Pulangan 65 Tunai (RM)' is a nonstandard phrase arrangement.",
#         "3. English: 'Note: The Cashback awarded will be rounded (up or down) to the settlement of the nearest Ringgit Malaysia'; BM compresses the rounding note and omits 'settlement'."
#       ],
#       "explanation": "Spelling error and poor phrase construction in BM, 'settlement' word omitted."
#     },
#     {
#       "location": "Section 2 - Eligibility & Participation: Clause (a), (i)",
#       "doc1": {
#         "content": "- (i) the Cardholders of WISE Card account must be valid and in good standing, not overdue in payment and must not be closed or terminated by either the Cardholders or HLB;"
#       },
#       "doc2": {
#         "content": "- (i) Akaun Kad WISE Pemegang Kad mestilah sah, mempunyai rekod baik, bayaran tidak bertunggak dan tidak ditutup atau ditamatkan oleh sama ada oleh Pemegang Kad atau HLB;"
#       },
#       "discrepancies": [
#         "1. English 'the Cardholders of WISE Card account' is 'Akaun Kad WISE Pemegang Kad' (order reversed in BM).",
#         "2. BM says 'atan ditutup atau ditamatkan oleh sama ada oleh Pemegang Kad atau HLB'; extra repeated 'oleh'.",
#         "3. 'in good standing, not overdue in payment' is merged in BM as 'mempunyai rekod baik, bayaran tidak bertunggak', separating the qualities differently.",
#         "4. English 'must not be closed or terminated by either the Cardholders or HLB' is 'tidak ditutup atau ditamatkan oleh sama ada oleh Pemegang Kad atau HLB', which adds superfluous 'oleh' and may create ambiguity."
#       ],
#       "explanation": "Syntactic errors, repetition, and nonstandard translation of 'good standing' and account status."
#     },
#     {
#       "location": "Section 2(a)(ii)",
#       "doc1": {
#         "content": "- (ii) the Cardholders must not be in breach of any of these Terms and Conditions and/or the terms and conditions of the Agreement;"
#       },
#       "doc2": {
#         "content": "- (ii) Pemegang Kad mestilah tidak melanggar mana-mana Terma dan Syarat ini dan/atau terma dan syarat Perjanjian;"
#       },
#       "discrepancies": [
#         "1. English: 'must not be in breach of any of these Terms and Conditions'. BM: 'mestilah tidak melanggar mana-mana Terma dan Syarat ini' — translation is literal, but BM omits possessive 'of'."
#       ],
#       "explanation": "Translation is literal but omits possessive context."
#     },
#     {
#       "location": "Section 2(a)(iii)",
#       "doc1": {
#         "content": "- (iii) eligibility  will  be  revoked  in  respect  of  the  Cardholders  who  have  committed  or  are suspected of committing any fraudulent, unlawful or wrongful acts in relation to any of the facilities granted by HLB or have been declared bankrupt (pursuant to a petition by either banks or by any third party) or are subject to any bankruptcy proceedings at any time prior to, during or after the availability of the Programme."
#       },
#       "doc2": {
#         "content": "- (iii)  Kelayakan  akan  dibatalkan  bagi  Pemegang  Kad  yang  telah  melakukan  atau  disyaki melakukan sebarang penipuan atau kesalahan undang-undang berkaitan dengan manamana kemudahan yang diberi oleh HLB atau telah diisytiharkan muflis (menurut petisyen oleh  sama  ada  bank  atau  mana-mana  pihak  ketiga)  atau  bakal  dikenakan  prosiding kemuflisan pada bila-bila masa sebelum, semasa atau selepas Program selesai."
#       },
#       "discrepancies": [
#         "1. BM 'sebarang penipuan atau kesalahan undang-undang' omits 'wrongful acts' from English.",
#         "2. BM: 'bakal dikenakan prosiding kemuflisan pada bila-bila masa sebelum, semasa atau selepas Program selesai' translates as 'may be subjected to bankruptcy proceedings at any time before, during or after the Programme ends'; English says 'prior to, during or after the availability of the Programme', which is not literally 'after Programme ends'.",
#         "3. English: 'pursuant to a petition by either banks or by any third party'; BM: 'petisyen oleh  sama  ada  bank  atau  mana-mana  pihak  ketiga' (missing 'either ... or by', and extra spaces creating ambiguity)."
#       ],
#       "explanation": "BM omits mention of 'wrongful acts', changes the timeline (after Programme ends, instead of after availability), and has ambiguous/jumbled connective words."
#     },
#     {
#       "location": "Section 3(a) Definition of Eligible Retail Transaction",
#       "doc1": {
#         "content": "- (a) The term ' Eligible Retail Transaction ' shall refer to any retail purchase transaction made locally and overseas, including online transactions which are charged to the WISE Card (i.e. only applicable to the Principal WISE Cards) but EXCLUDE the following transactions (the list below is not exhaustive and HLB reserves the sole right to determine if a transaction fall within the definition of Eligible Retail Transactions):-"
#       },
#       "doc2": {
#         "content": "- (a) Terma ' Transaksi Runcit Layak ' bermaksud apa-apa transaksi belian runcit yang dibuat di dalam dan luar negara, termasuk transaksi dalam talian yang dicaj kepada Kad WISE (hanya tertakluk  pada  Kad  WISE  Utama ) tetapi TIDAK TERMASUK transaksi berikut (senarai di bawah  ini  tidak  lengkap  dan  HLB  berhak  menentukan  sama  ada  sesuatu  transaksi  itu terangkum dalam takrif Transaksi Runcit atau Pembelanjaan Runcit):"
#       },
#       "discrepancies": [
#         "1. English 'retail purchase transaction' is 'transaksi belian runcit' in BM; direct translation.",
#         "2. English: 'only applicable to the Principal WISE Cards'; BM: 'hanya tertakluk  pada  Kad  WISE  Utama', missing the plural 'Cards'.",
#         "3. English 'HLB reserves the sole right to determine if a transaction fall within the definition of Eligible Retail Transactions'; BM: 'HLB  berhak  menentukan  sama  ada  sesuatu  transaksi  itu terangkum dalam takrif Transaksi Runcit atau Pembelanjaan Runcit', which introduces 'Pembelanjaan Runcit' instead of just 'Transaksi Runcit Layak'; broadens scope.",
#         "4. English: (the list below is not exhaustive). BM: '(senarai di bawah  ini  tidak  lengkap)', correct but less formal."
#       ],
#       "explanation": "BM adds an extra possible meaning for Eligible Retail Transactions ('Pembelanjaan Runcit'), and only uses singular/plural for cards inconsistently."
#     },
#     {
#       "location": "Section 3(a)(vi)",
#       "doc1": {
#         "content": "- (vi) disputed transactions that are subsequently reversed from the account of the Principal Cardholder; and/or"
#       },
#       "doc2": {
#         "content": "- (vi)  Transaksi  yang  dipertikaikan  yang  kemudiannya  dibalikkan  daripada  akaun  Pemegang Kad; dan/atau"
#       },
#       "discrepancies": [
#         "1. English: 'from the account of the Principal Cardholder'; BM: 'daripada akaun Pemegang Kad'; omits clarification of 'Principal'."
#       ],
#       "explanation": "BM does not specify the main/Principal cardholder."
#     },
#     {
#       "location": "Section 3(a)(vii)",
#       "doc1": {
#         "content": "- (vii) QR Pay Transactions made via the HLB Connect App."
#       },
#       "doc2": {
#         "content": "- (vii) Transaksi QR Pay melalui HLB Connect App."
#       },
#       "discrepancies": [
#         "1. English: 'QR Pay Transactions made via the HLB Connect App' is in BM as 'Transaksi QR Pay melalui HLB Connect App'; missing 'made' ('dilakukan' or equivalent)."
#       ],
#       "explanation": "'Made' omitted from BM, which affects clarity."
#     },
#     {
#       "location": "Section 3(a), Paragraph After Exclusion List",
#       "doc1": {
#         "content": "Transactions that are not Eligible Retail Transactions will not be entitled to any Cashback and the amount spent  from  these  transactions  will  not  contribute  to  or  form  part  of  the  minimum  spend requirement of Ringgit Malaysia One Thousand (RM1,000) or any spend below RM1,000 for each calendar month."
#       },
#       "doc2": {
#         "content": "Transaksi  yang  bukan  merupakan  Transaksi  Runcit  Layak  tidak  akan  menerima  apa-apa Pulangan  Tunai  dan  amaun  yang  dibelanjakan  daripada  transaksi-transaksi  ini  tidak  akan menyumbang atau menjadi sebahagian perbelanjaan minimum  Ringgit Malaysia Satu Ribu (RM1,000) bagi setiap bulan kalendar."
#       },
#       "discrepancies": [
#         "1. BM omits explicit reference to 'or any spend below RM1,000 for each calendar month'.",
#         "2. English: 'not contribute to or form part of the minimum spend requirement of...' BM: 'tidak akan menyumbang atau menjadi sebahagian perbelanjaan minimum...', omits word 'requirement'."
#       ],
#       "explanation": "BM omits the clause 'or any spend below RM1,000 for each calendar month' and the word 'requirement', possibly changing the scope."
#     },
#     {
#       "location": "Section 3, 'All government, JomPAY and FPX transactions' Paragraph",
#       "doc1": {
#         "content": "For all government, JomPAY and/or FPX transactions, the amount spent from these transactions will contribute and form part of the minimum spend of Ringgit Malaysia One Thousand (RM1,000) for each calendar month. However, these transactions will not be entitled to any Cashback."
#       },
#       "doc2": {
#         "content": "Bagi  semua  transaksi  berkaitan  kerajaan,  JomPAY  dan/atau  transaksi  FPX,  amaun  yang dibelanjakan daripada transaksi ini akan menyumbang dan menjadi sebahagian perbelanjaan minimum Ringgit  Malaysia  Satu  Ribu  (RM1,000)    bagi  setiap  bulan  kalendar.  Akan  tetapi, transaksi-transaksi ini tidak akan layak menerima Pulangan Tunai."
#       },
#       "discrepancies": [
#         "1. English: 'the amount spent from these transactions will contribute and form part of the minimum spend ... for each calendar month'. BM: 'amaun  yang dibelanjakan ... akan menyumbang dan menjadi sebahagian perbelanjaan minimum ... bagi setiap bulan kalendar'; missing 'requirement' of minimum spend.",
#         "2. English: 'However, these transactions will not be entitled to any Cashback.' BM: 'tidak akan layak menerima Pulangan Tunai.' — literal translation, but omits 'entitled to'."
#       ],
#       "explanation": "Word choices and requirement scope differ."
#     },
#     {
#       "location": "Section 3(b), (c) - Definitions",
#       "doc1": {
#         "content": "- (b) The  term  ' HLB  Connect  App '  refers  to  the  Hong  Leong  Bank  Connect  Mobile  Banking Application.\n- (c) The term ' QR Pay Transaction ' means retail transactions made via the HLB Connect App using the HLB QR Pay feature."
#       },
#       "doc2": {
#         "content": "- (b)  Istilah ' HLB Connect App ' bermaksud Perbankan Mudah Alih Hong Leong Connect.\n- (c)  Istilah  ' Transaksi  QR  Pay' bermaksud  transaksi  runcit  dibuat  melalui  HLB  Connect  App mengunakan QR Pay."
#       },
#       "discrepancies": [
#         "1. English 'the Hong Leong Bank Connect Mobile Banking Application' is 'Perbankan Mudah Alih Hong Leong Connect' in BM; omits direct reference to 'Application'.",
#         "2. English 'the HLB QR Pay feature' is shortened to 'mengunakan QR Pay' in BM, omitting 'feature' and misspelling 'menggunakan' as 'mengunakan'."
#       ],
#       "explanation": "BM omits 'application' and has a spelling error in 'mengunakan'."
#     },
#     {
#       "location": "Section 3(d): Cashback Calculation",
#       "doc1": {
#         "content": "- (d) The Cashback will be calculated at the end of each calendar month based on the rate as shown in Table 1 above and is non-cumulative from the previous month. For the avoidance of doubt, Weekdays refer to Mondays to Fridays and Weekends refer to Saturdays and Sundays."
#       },
#       "doc2": {
#         "content": "- (d)  Pulangan Tunai akan dikira pada akhir setiap bulan kalendar berdasarkan kadar seperti tertera dalam Jadual dalam Jadual 1 di atas dan tidak kumulatif dari bulan sebelum. Bagi mengelakkan keraguan, Hari Minggu bermaksud Isnin hingga Jumaat dan Hujung Minggu bermaksud Sabtu dan Ahad."
#       },
#       "discrepancies": [
#         "1. BM: 'berdasarkan kadar seperti tertera dalam Jadual dalam Jadual 1 di atas' repeats 'Jadual' (should only be once, error).",
#         "2. English 'non-cumulative from the previous month' is 'tidak kumulatif dari bulan sebelum' in BM; BM omits 'from' in context.",
#         "3. BM misspells 'Jadual 1 di atas' as twice 'Jadual dalam Jadual'."
#       ],
#       "explanation": "Repetition ('Jadual dalam Jadual'), clarity of non-cumulative condition, and mapping of weekdays/weekends are main issues."
#     },
#     {
#       "location": "Section 3(e): Cashback Rounding and Crediting",
#       "doc1": {
#         "content": "- (e) The Cashback awarded will be rounded (up or down) to the settlement of the nearest Ringgit Malaysia (' RM '). The Cashback credits will be utilized towards any outstanding balances due on the WISE Card account. For the avoidance of doubt, any Cashback due to the Cardholders will  be  credited  to  the  WISE  Card  account  on  the  following  month  and  reflected  in  the Cardholders' statement. In the event the Cashback due to the Cardholders falls on or after the date of the Cardholders' statement, the Cashback will only be reflected in the Cardholders' statement in the following month."
#       },
#       "doc2": {
#         "content": "- (e)  Pulangan Tunai yang dianugerahkan akan dibundarkan (ke atas atau bawah) kepada kiraan Ringgit  Malaysia  (' RM ') yang  terhampir.  Kredit  Pulangan  Tunai  akan  digunakan  untuk menampung apa-apa baki belum lunas dalam akaun Kad WISE. Bagi mengelakkan keraguan, Pulangan Tunai yang kena dibayar kepada Pemegang Kad akan dikreditkan ke dalam akaun Kad  WISE  pada  bulan  berikut  dan  dipaparkan  dalam  Penyata  Pemegang  Kad.  Sekiranya Pulangan Tunai yang kena dibayar kepada Pemegang Kad matang pada atau selepas tarikh Penyata  Pemegang  Kad,  maka  Pulangan  Tunai  hanya  akan  dipaparkan  dalam  Penyata Pemegang Kad pada bulan berikutnya."
#       },
#       "discrepancies": [
#         "1. English: 'rounded (up or down) to the settlement of the nearest Ringgit Malaysia'; BM: 'dibundarkan (ke atas atau bawah) kepada kiraan Ringgit Malaysia ('RM') yang terhampir' — 'settlement' is translated as 'kiraan', which means 'calculation/count', not settlement.",
#         "2. English 'Cashback credits will be utilized towards any outstanding balances...' BM: 'Kredit Pulangan Tunai akan digunakan untuk menampung apa-apa baki belum lunas' — omits 'utilized' and weakens the formality.",
#         "3. English makes three references to 'Cardholders' statement', BM four.",
#         "4. 'credited to the WISE Card account... and reflected in the Cardholders' statement' is translated as 'dikreditkan ke dalam akaun Kad  WISE  pada  bulan  berikut  dan  dipaparkan  dalam  Penyata  Pemegang  Kad', BM omits 'following month' in second occurrence.",
#         "5. English: 'the Cashback will only be reflected in the Cardholders' statement in the following month.' BM: 'maka  Pulangan  Tunai  hanya  akan  dipaparkan  dalam  Penyata Pemegang Kad pada bulan berikutnya.' BM omits 'the Cashback due to the Cardholders falls on or after the date'."
#       ],
#       "explanation": "BM uses 'kiraan' instead of 'settlement', omits some qualifiers, and alters phrase order."
#     },
#     {
#       "location": "Section 3(f): Foreign Transactions and Currency Conversion",
#       "doc1": {
#         "content": "- (f) The Cashback is awarded to the Cardholders based on the total posted amount of Eligible Retail  Transactions  in  RM  charged  to  the  WISE  Card.  All  overseas  transactions  and transactions performed in foreign currencies will be converted to RM at such rate of exchange as determined by HLB at its discretion."
#       },
#       "doc2": {
#         "content": "- (f) Pulangan Tunai diberi kepada Pemegang Kad berdasarkan jumlah amaun tercatat Transaksi Runcit  yang  Layak  dalam  RM  dicaj  kepada  Kad  WISE.  Semua  transaksi  luar  negara  dan transaksi yang dilakukan dalam mata wang asing akan ditukar kepada RM mengikut kadar pertukaran yang ditentukan oleh HLB atas budi bicaranya yang mutlak."
#       },
#       "discrepancies": [
#         "1. English: 'at its discretion' is 'atas budi bicaranya yang mutlak' in BM — BM adds 'mutlak' (absolute).",
#         "2. English: 'total posted amount ... charged to the WISE Card'; BM reverses order.",
#         "3. Both versions are conceptually similar, only minor qualifying word addition in BM."
#       ],
#       "explanation": "Small difference: BM adds 'yang mutlak' (absolute discretion) not in English."
#     },
#     {
#       "location": "Section 3(h): Cashback Rate Revision",
#       "doc1": {
#         "content": "- (h) HLB reserves its rights from time to time, with prior notice, to revise the rate of the Cashback awarded at its discretion."
#       },
#       "doc2": {
#         "content": "- (h)  HLB berhak dari semasa ke semasa, setelah notis awal diberi, meminda kadar Pulangan Tunai menurut budi bicaranya yang mutlak."
#       },
#       "discrepancies": [
#         "1. English: 'with prior notice,' BM: 'setelah notis awal diberi,' (different emphasis).",
#         "2. BM adds 'yang mutlak' (absolute discretion) again; English says only 'at its discretion'."
#       ],
#       "explanation": "Minor wording and qualifying difference."
#     },
#     {
#       "location": "Section 3(i): Merchant Category Assignment",
#       "doc1": {
#         "content": "- (i) The  assignment  of  the  Merchant  Category  and  the  Merchant  Category  Code  for  each merchant  is  subject  to  classification  by  the  respective  acquiring  banks  and  it  is  the responsibility of the particular acquiring bank to assign the correct Merchant Category and Merchant Category Code. HLB shall  not be held responsible for  any  incorrect  or  different assignment of the Merchant Category and Merchant Category Code that may result in (i) a transaction not being categorised as an Eligible Retail Transaction and/or (ii) non-posting of the Cashback for Eligible Retail Transaction at the eligible merchants. The Cardholder shall not  be  entitled  to  claim  for  any  compensation  against  HLB  for  such  non-posting  of  the Cashback due to incorrect or different assignment of the Merchant Category by the respective merchant's acquiring bank."
#       },
#       "doc2": {
#         "content": "- (i) Penetapan Kategori Peniaga dan Kod Kategori Peniaga bagi setiap peniaga adalah tertakluk kepada  pengelasan  oleh  bank-bank  pemperoleh  masing-masing  dan  bank  pemeroleh berkenaan bertanggungjawab menentukan Kategori Peniaga dan Kod Kategori Peniaga yang betul.  HLB  tidak  akan  bertanggungjawab  terhadap  penetapan  Kategori  Peniaga  dan  Kod Kategori  Peniaga  yang  tidak  betul  atau  berbeza  sehingga  menyebabkan  (i)  transaksi  tidak dikategorikan  sebagai  Transaksi  Runcit  Layak  dan/atau  (ii)  Pulangan  Tunai  bagi  Transaksi Runcit  Layak  tidak    tercatat  pada  peniaga  yang  layak.  Pemegang  Kad  tidak  akan  berhak menuntut  apa-apa  pampasan  terhadap  HLB  atas  Pulangan  Tunai  tidak  tercatat  lantaran penetapan  Kategori  Peniaga  yang  tidak  betul  atau  berbeza  oleh  bank  pemeroleh  peniaga masing-masing."
#       },
#       "discrepancies": [
#         "1. English: 'non-posting of the Cashback for Eligible Retail Transaction at the eligible merchants.' BM omits 'at the eligible merchants' ('pada peniaga yang layak' appears, but not in same clause).",
#         "2. 'The Cardholder shall not be entitled to claim for any compensation against HLB' is translated as 'Pemegang Kad tidak akan berhak menuntut  apa-apa  pampasan terhadap HLB', omitting sense of 'shall not be entitled to claim for any compensation'.",
#         "3. BM adds 'lantaran' (due to/because of), not in English.",
#         "4. English: 'assignment of the Merchant Category and the Merchant Category Code that may result in' is compressed in BM.",
#         "5. BM omits 'by the respective merchant's acquiring bank' in last instance."
#       ],
#       "explanation": "Numerous condensing of English material, compressed phrases, and omissions."
#     },
#     {
#       "location": "Section 3(j): T&Cs Revision Period",
#       "doc1": {
#         "content": "- (j) HLB may from time to time, at its discretion, by giving prior notice of at least twenty-one (21) calendar days to the Cardholders, change, revise, or vary any of the T&Cs herein."
#       },
#       "doc2": {
#         "content": "- (j) HLB boleh dari semasa ke semasa, atas budi bicaranya yang mutlak, setelah memberi notis awal  sekurang-kurangnya  dua  puluh  satu  (21)  hari  kalendar  kepada  Pemegang  Kad, mengubah, meminda, atau menukar mana-mana T&S ini."
#       },
#       "discrepancies": [
#         "1. BM: Adds 'yang mutlak' (absolute discretion) not in English.",
#         "2. Sequence of 'at its discretion, by giving prior notice ...' switched in BM.",
#         "3. English: 'change, revise, or vary'; BM: 'mengubah, meminda, atau menukar' (literal translation but not standardized term for 'vary')."
#       ],
#       "explanation": "BM adds 'absolute discretion' qualifier, and rearranges clause order."
#     },
#     {
#       "location": "Section 3(k): Reversal of Cashback for Reversed Transactions",
#       "doc1": {
#         "content": "- (k) The Cardholders' minimum spend amount will determine the Cashback entitlement rates of the Cardholders based on Table 1 above. If Cashback is given in respect of any Eligible Retail Transaction  which  is  subsequently  reversed,  the  reversal  will  result  in  the  corresponding Cashback being reversed regardless of the original transaction posting date. Any reversed transaction and/or cancelled transaction will be excluded from receiving the Cashback."
#       },
#       "doc2": {
#         "content": "- (k)  Amaun perbelanjaan minimum Pemegang Kad akan menentukan kadar kelayakan Pulangan Tunai Pemegang Kad berdasarkan Jadual 1 di atas. Jika Pulangan Tunai diberi bagi manamana  Transaksi  Runcit  Layak  yang  kemudiannya  dibalikkan,  maka  pembalikan  itu  akan menyebabkan  Pulangan  Tunai  bersamaan  turut  dibalikkan  tanpa  mengira  tarikh  tercatat transaksi  asal.  Sebarang  transaksi  dibalikkan  dan/atau  transaksi  yang  dibatalkan  akan dikecualikan daripada menerima Pulangan Tunai."
#       },
#       "discrepancies": [
#         "1. English: 'regardless of the original transaction posting date' BM: 'tanpa mengira tarikh tercatat transaksi asal'. BM omits the word 'original' in key phrase.",
#         "2. English: 'Any reversed transaction and/or cancelled transaction will be excluded from receiving the Cashback.' BM: 'akan dikecualikan daripada menerima Pulangan Tunai.' (literal, no content loss)."
#       ],
#       "explanation": "BM misses 'original' before 'posting date'."
#     },
#     {
#       "location": "Section 4 - Annual Fee",
#       "doc1": {
#         "content": "Annual Fee will be levied as follows:\n\n| Principal Cardholder     | RM98   |\n|--------------------------|--------|\n| Supplementary Cardholder | RM48   |\n\nThere is no annual fee waiver for WISE Card."
#       },
#       "doc2": {
#         "content": "Fi Tahunan akan dikenakan seperti berikut:\n\n| Pemegang Kad Utama    | RM98   |\n|-----------------------|--------|\n| Pemegang Kad Tambahan | RM48   |\n\nFi tahunan tidak akan dikecualikan untuk Kad WISE."
#       },
#       "discrepancies": [
#         "1. 'Annual fee waiver' in English is 'tidak akan dikecualikan' in BM, but not literally 'waiver'.",
#         "2. 'Supplementary Cardholder' is translated as 'Pemegang Kad Tambahan', which is standard, but may invite confusion for those used to 'tambahan' meaning 'additional'."
#       ],
#       "explanation": "BM omits explicit reference to 'waiver' and changes formality."
#     },
#     {
#       "location": "Section 5 - Product Features Variation",
#       "doc1": {
#         "content": "HLB reserves the right to amend, vary or alter any of the product features for the WISE Card or withdraw the WISE Card at any time with prior notice to the Cardholders and such amendments shall be effective on such date that HLB may elect to adopt. Subsequently, HLB may at its discretion mail directly to the Cardholders or notify in the mass media or post a notice at HLB's banking hall or at HLB's website at www.hlb.com.my or any method which HLB deems practical for such additions, modifications or amendments of the product features."
#       },
#       "doc2": {
#         "content": "HLB  berhak  meminda,  mengubah  atau  menukar  mana-mana  ciri  produk  bagi  Kad  WISE  atau menarik balik Kad WISE pada bila-bila masa setelah notis awal diberi kepada Pemegang Kad. Pertukaran  dan  pemindaan  tersebut  akan  berkuat  kuasa  pada  tarikh  yang  dipilih  oleh  HLB. Berikutan  itu,  HLB  boleh  atas  budi  bicaranya  menghantar  terus  kepada  Pemegang  Kad  atau memaklumkan melalui media massa atau menghebahkan notis dalam dewan perbankan HLB Bank atau laman web HLB di www.hlb.com.my atau apa-apa cara yang HLB anggap sesuai tentang penambahan, pengubahsuaian atau pemindaan ciri-ciri produk itu."
#       },
#       "discrepancies": [
#         "1. 'amend, vary, or alter' is translated as 'meminda, mengubah, atau menukar' — not literal, may create ambiguity.",
#         "2. English 'such amendments shall be effective on such date that HLB may elect to adopt' is 'Pertukaran dan pemindaan tersebut akan berkuat kuasa pada tarikh yang dipilih oleh HLB' — omitting 'may elect to adopt', which is more conditional.",
#         "3. English: 'at its discretion mail directly to the Cardholders or notify in the mass media or post a notice at HLB's banking hall or at HLB's website ...' BM: 'menghantar  terus  kepada  Pemegang  Kad  atau memaklumkan melalui media massa atau menghebahkan notis dalam dewan perbankan HLB Bank atau laman web HLB ...' BM omits 'at its discretion' for mailing directly.",
#         "4. 'At any time with prior notice' in English is 'pada bila-bila masa setelah notis awal diberi...' in BM — restructured and qualifer omitted.",
#         "5. English 'any method which HLB deems practical ...' BM: 'apa-apa cara yang HLB anggap sesuai ...', which omits 'practical' specificity."
#       ],
#       "explanation": "'May elect to adopt' becomes 'chosen by HLB', qualifiers and some formal language omitted, and terms like 'practical' become 'suitable'."
#     },
#     {
#       "location": "Section 5 - Additional Clause (BM only)",
#       "doc1": {
#         "content": "If you have any enquiries regarding these T&Cs, you may seek clarification from our staff who attended to you. Alternatively, please email us at hlonline@hlbb.hongleong.com.my."
#       },
#       "doc2": {
#         "content": "Jika anda mempunyai sebarang pertanyaan mengenai T&S ini, anda boleh mendapatkan penjelasan daripada kakitangan kami yang sedang melayan anda. Sebagai alternatif, sila e-mel kepada kami di hlonline@hlbb.hongleong.com.my."
#       },
#       "discrepancies": [
#         "1. English: 'staff who attended to you' is 'kakitangan kami yang sedang melayan anda' in BM, translating 'attending staff' as 'currently serving you'.",
#         "2. 'Alternatively, please email us at ...' is 'Sebagai alternatif, sila e-mel kepada kami di ...' — 'please' is stated in English only, not BM."
#       ],
#       "explanation": "Translation for 'attended to you' differs, changing temporal context."
#     },
#     {
#       "location": "Section 5 and 6 - Reward Points Clause (BM Only)",
#       "doc1": {
#         "content": "[No equivalent clause for reward points.]"
#       },
#       "doc2": {
#         "content": "## 5. Mata Ganjaran\n\nMata ganjaran tidak diberi bagi Kad WISE."
#       },
#       "discrepancies": [
#         "1. BM includes a clause 'Mata ganjaran tidak diberi bagi Kad WISE' (No reward points are given for WISE Card) which is missing in English."
#       ],
#       "explanation": "BM document contains a product feature clause about reward points that does not exist in the English version."
#     }
#   ]
# }
# ```

# %%
import json
import re

json_str = result
match = re.search(r"```json\s*(\{.*\})\s*```", result, re.DOTALL)
if match:
    json_str = match.group(1)
try:
    result_dict = json.loads(json_str)  # Attempt to parse the JSON
    if result_dict.get("flags"):  # Check if "flags" key exists and is not empty
        print(json.dumps(result_dict, indent=2))
    else:
        print("No flags found in the result.")
except json.JSONDecodeError as e:
    print(f"Error decoding JSON: {e}")
# Out:
# {
#   "total": 56,
#   "flags": [
#     {
#       "location": "Document Title and Section Header",
#       "doc1": {
#         "content": "<span style=\"color: red\">HONG LEONG WISE CREDIT CARD TERMS AND CONDITIONS (Versi Bahasa Malaysia)</span> Last updated 10 December 2024"
#       },
#       "doc2": {
#         "content": "<span style=\"color: red\">TERMA DAN SYARAT KAD KREDIT WISE HONG LEONG (English Version)</span> Dikemas Kini 10 Disember 2024"
#       },
#       "discrepancies": [
#         "1. Language/label mismatch: English version refers to '(Versi Bahasa Malaysia)' while BM version refers to '(English Version)'.",
#         "2. English has 'Last updated 10 December 2024'; BM has 'Dikemas Kini 10 Disember 2024'.",
#         "3. Language code switch: headers in English at top of English document but BM at top of BM document."
#       ],
#       "explanation": "Document titles/section headers do not fully correspond. Language codes/indicators are swapped. Date format and wording also differ between versions."
#     },
#     {
#       "location": "Introduction/Opening Paragraph",
#       "doc1": {
#         "content": "These HLB WISE Credit Card (' WISE Card ') Terms and Conditions (' T&Cs ') are to be read together with the Hong Leong Bank Berhad's (\" HLB \") Cardholder Agreement (\" the Agreement \"). Save and except for the variations set out below, all the terms and conditions of the Agreement shall apply. In the event of any discrepancy or inconsistency between the terms and conditions of the Agreement and these T&Cs, these T&Cs shall prevail in so far as they are applicable to the WISE Card. By accepting the WISE Card, the Cardholder  (as  defined  herein)  agrees  to  be  bound  by  these  T&Cs  and  terms  and  conditions  of  the Agreement."
#       },
#       "doc2": {
#         "content": "Terma dan Syarat (' T&S ') Kad Kredit WISE HLB (' Kad WISE ') hendaklah dibaca bersama dengan Perjanjian Pemegang Kad (' Perjanjian ') Hong Leong Bank Berhad (\" HLB \"). Selain daripada variasi yang dinyatakan di bawah, semua terma dan syarat Perjanjian hendaklah diterima pakai. Sekiranya terdapat percanggahan atau ketidakselarasan antara terma dan syarat Perjanjian dengan terma dan syarat T&S ini  T&S ini ini hendaklah diutamakan setakat mana yang berkenaan dengan Kad WISE. Dengan menerima Kad WISE, Pemegang Kad bersetuju untuk terikat dengan T&S ini dan Perjanjian."
#       },
#       "discrepancies": [
#         "1. The phrase 'These HLB WISE Credit Card (' WISE Card ') Terms and Conditions (' T&Cs ') are to be read together with' is translated as 'Terma dan Syarat (' T&S ') Kad Kredit WISE HLB (' Kad WISE ') hendaklah dibaca bersama dengan', omitting 'these' and reversing the order.",
#         "2. English 'Cardholder Agreement (\" the Agreement \")' translated as 'Perjanjian Pemegang Kad (' Perjanjian ')', minor switch in order and omission of 'Cardholder' in quotes in BM.",
#         "3. English 'Save and except for the variations set out below, all the terms and conditions of the Agreement shall apply.' translated as 'Selain daripada variasi yang dinyatakan di bawah, semua terma dan syarat Perjanjian hendaklah diterima pakai.'; the phrase 'shall apply' in English is more direct, while BM's 'hendaklah diterima pakai' means 'shall be accepted and applied', a mild interpretation difference.",
#         "4. English 'In the event of any discrepancy or inconsistency between the terms and conditions of the Agreement and these T&Cs, these T&Cs shall prevail in so far as they are applicable to the WISE Card.' BM omits 'in so far as they are applicable to the WISE Card' (BM: 'setakat mana yang berkenaan dengan Kad WISE'), which corresponds, but the BM placement at the end changes clarity.",
#         "5. English 'Cardholder (as defined herein)' is missing from BM version.",
#         "6. BM 'T&S ini ini' is a repetition error.",
#         "7. English 'and terms and conditions of the Agreement' is simply 'dan Perjanjian' in BM, omitting explicit reference to 'terma dan syarat Perjanjian'.",
#         "8. English 'By accepting the WISE Card, the Cardholder (as defined herein) agrees to be bound by these T&Cs and terms and conditions of the Agreement.' BM omits the clarification '(as defined herein)'."
#       ],
#       "explanation": "Numerous minor terminology discrepancies, a repetition error in BM, missing explanations in BM (e.g. 'as defined herein'), as well as word order swaps, add up to several content, clarity, and structure variations."
#     },
#     {
#       "location": "Section 1(a) Programme Eligibility - Opening Clause",
#       "doc1": {
#         "content": "- (a) Principal Cardholders of the WISE Card (' Cardholders \") will be awarded with cashback of up to 15% (' Cashback '), subject to the following:"
#       },
#       "doc2": {
#         "content": "- (a)  Pemegang  Kad  Utama  WISE  (' Pemegang  Kad  Utama ')  akan  menerima  pulangan  tunai sehingga 15% (' Pulangan Tunai '), tertakluk kepada yang berikut:"
#       },
#       "discrepancies": [
#         "1. English 'Principal Cardholders of the WISE Card (' Cardholders \")' is explicitly describing both Principal Cardholders and the 'WISE Card', while BM is 'Pemegang Kad Utama WISE (' Pemegang Kad Utama '), omitting a general 'Cardholders' definition.",
#         "2. English 'will be awarded with cashback of up to 15%' is 'akan menerima pulangan tunai sehingga 15%' in BM. The word 'up to' is correctly 'sehingga', but English's 'awarded with' (passive) is 'akan menerima' (active).",
#         "3. English uses double 'quotes' after 'Cardholders', suggesting a typo.",
#         "4. Word 'cashback' is not translated literally; BM uses 'pulangan tunai'.",
#         "5. English puts 'Cashback' in brackets and quotation marks; BM uses single quotes on 'Pulangan Tunai'.",
#         "6. BM omits 'of the WISE Card', and both versions lack symmetry in reference labels (Cardholders/Pemegang Kad Utama)."
#       ],
#       "explanation": "Discrepancies largely center on missing/added descriptors, word order, definition phrasing, and possible typographical issues."
#     },
#     {
#       "location": "Section 1(a)(i)",
#       "doc1": {
#         "content": "- (i) a minimum spend of Ringgit Malaysia One Thousand (RM1,000) on the Eligible Retail Transactions (as defined under Clause 3(a) herein) in each calendar month where the minimum spend is calculated after taking into account all reversals (if any);"
#       },
#       "doc2": {
#         "content": "- (i) perbelanjaan minimum Ringgit Malaysia Satu Ribu (RM1,000) dari Transaksi Runcit Layak (seperti ditakrif dalam Klausa 3(a) disini) pada setiap bulan calendar di mana perbelanjaan minimum dikira selepas mengambil kira semua pembalikan (jika ada);"
#       },
#       "discrepancies": [
#         "1. English 'calendar month' is 'bulan calendar' in BM, which should be 'bulan kalendar' (spelling error and inconsistent language mixing).",
#         "2. 'from Eligible Retail Transactions' is translated as 'dari Transaksi Runcit Layak', direct translation, but English says 'on the Eligible Retail Transactions', this is not a major clarity loss but word choice differs.",
#         "3. English 'where the minimum spend is calculated after taking into account all reversals (if any)' is 'di mana perbelanjaan minimum dikira selepas mengambil kira semua pembalikan (jika ada)'; consistent meaning, but English used 'minimum spend', BM repeats 'perbelanjaan minimum', and wording is slightly different.",
#         "4. English: 'as defined under Clause 3(a) herein', BM: 'seperti ditakrif dalam Klausa 3(a) disini' (possible spelling/localization, and 'di sini' should be separated)."
#       ],
#       "explanation": "Punctuation and spelling inconsistencies, language mixing, word order, and minor literal translation issues."
#     },
#     {
#       "location": "Section 1(a)(ii)",
#       "doc1": {
#         "content": "- (ii) such minimum spend of Ringgit Malaysia One Thousand (RM1,000) on the Eligible Retail Transactions are posted in the same calendar month; and"
#       },
#       "doc2": {
#         "content": "- (ii) perbelanjaan  minimum  Ringgit  Malaysia  Satu  Ribu  (RM1,000)  tersebut  atas  Transaksi Runcit Layak tercatat dalam bulan kalendar yang sama; dan"
#       },
#       "discrepancies": [
#         "1. 'are posted' is more clearly 'tercatat' as a verb in BM; ok, but English's passive is not matched.",
#         "2. 'on the Eligible Retail Transactions' is 'atas Transaksi Runcit Layak' (literal), omitting preposition difference.",
#         "3. 'calendar month' is correctly 'bulan kalendar' here, showing inconsistency with previous 'bulan calendar'.",
#         "4. No major loss of meaning, but missing considerations for word-for-word passive voice."
#       ],
#       "explanation": "Slight formality difference, but mostly accurate. Only minor differences in voice and preposition usage."
#     },
#     {
#       "location": "Section 1(a)(iii)",
#       "doc1": {
#         "content": "- (iii) such  Eligible  Retail  Transactions  fall  under  the  permitted  categories  (i.e.  Spend Category and Eligible Merchant Category Codes (MCC), Merchants and/or Transactions) as listed in Table 1 below; or such other conditions as may be notified by HLB from time to time."
#       },
#       "doc2": {
#         "content": "- (iii)  Transaksi  Runcit  Layak  tersebut  termasuk  dalam  kategori  (iaitu  Kod  Kategori  Peniaga (MCC), Peniaga dan/atau Transaksi seperti tersenarai dalam Klausa 1(b) di bawah, atau apa-apa syarat lain yang dimaklumkan oleh HLB dari semasa ke semasa."
#       },
#       "discrepancies": [
#         "1. 'permitted categories (i.e. Spend Category and Eligible Merchant Category Codes (MCC), Merchants and/or Transactions)' is simplified to 'kategori (iaitu Kod Kategori Peniaga (MCC), Peniaga dan/atau Transaksi' \u2014 omits 'Spend Category' and 'Eligible' descriptors.",
#         "2. English points to 'Table 1 below'; BM says 'Klausa 1(b) di bawah', referring to a clause not a table (table/section reference inconsistency).",
#         "3. Word-for-word, BM version misses 'permitted' and 'eligible' adjectives.",
#         "4. In English, the clause ends with '; or such other conditions as may be notified by HLB from time to time.', BM puts 'atau apa-apa syarat lain yang dimaklumkan oleh HLB dari semasa ke semasa.' inside the clause with slightly different punctuation/scoping.",
#         "5. English syntax has a semicolon before 'or', BM uses a comma."
#       ],
#       "explanation": "BM omits 'Spend Category'/'Eligible' descriptors, refers to a section rather than Table 1, and there are formatting differences."
#     },
#     {
#       "location": "Section 1(b) Cashback Reference",
#       "doc1": {
#         "content": "- (b) The earning of the respective Cashback is stipulated in Table 1 below:"
#       },
#       "doc2": {
#         "content": "- (b)  Perolehan Pulangan Tunai masing - masing dipaparkan dalam Jadual 1 di bawah:"
#       },
#       "discrepancies": [
#         "1. 'is stipulated' is translated as 'dipaparkan', which is 'displayed/shown', omitting the legal formality of 'stipulated/determined' in English.",
#         "2. Word order of 'masing - masing' is split by spaces, should be 'masing-masing' (spelling/formatting error).",
#         "3. English: 'Table 1', BM: 'Jadual 1' (consistent, but no explicit note flag needed for term change)."
#       ],
#       "explanation": "BM uses weaker terminology ('displayed' vs 'stipulated') and contains a hyphenation/spacing error."
#     },
#     {
#       "location": "Table 1 - Row Headers",
#       "doc1": {
#         "content": "| Minimum Spend/ month (Posted Transaction)   | Spend category         | Eligible Merchant Category Codes (MCC), Merchants and/or Transactions | ..."
#       },
#       "doc2": {
#         "content": "| Perbelanjaan Minimum / Bulanan (Transaksi yang dipos)   | Kategori Perbelanjaan       | Kad Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak | ..."
#       },
#       "discrepancies": [
#         "1. 'Spend category' (English) translated as 'Kategori Perbelanjaan' (BM) \u2014 acceptable, no explicit omission.",
#         "2. English: 'Eligible Merchant Category Codes (MCC), Merchants and/or Transactions'; BM: 'Kad Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak'. BM adds 'Yang Layak', not in English.",
#         "3. English: 'Minimum Spend/ month (Posted Transaction)' = BM: 'Perbelanjaan Minimum / Bulanan (Transaksi yang dipos)'. BM uses 'yang dipos', not 'posted' as in English; word order varies."
#       ],
#       "explanation": "General translation differences and word additions without meaning drift, but specific words like 'Eligible' appear in BM where not in English version."
#     },
#     {
#       "location": "Table 1 - Dining Category, English",
#       "doc1": {
#         "content": "|                                             | Dining                 | \u2022 MCC: 5811/5812/5814 - All dining outlets. | ..."
#       },
#       "doc2": {
#         "content": "| RM1,000                                                 | Jamu Selera                 | \u2022 MCC: 5811/5812/5814 - Semua kedai makan | ..."
#       },
#       "discrepancies": [
#         "1. 'Dining' is 'Jamu Selera' in BM instead of a direct translation like 'Makan'; could cause confusion/inconsistency.",
#         "2. English 'All dining outlets' translated as 'Semua kedai makan'; the precise term 'outlets' is not explicitly translated.",
#         "3. BM omits the English row indicating an empty spend amount for Dining; assigns RM1,000 under 'Dining', inconsistent with placement in English table.",
#         "4. Placement of columns/row headers differs; 'Spend' is at left in English and directly with category in BM."
#       ],
#       "explanation": "The main issue is the translation of 'Dining' (not literal, leading to possible confusion with regular meals), and Table row structure/placement is not perfectly mirrored."
#     },
#     {
#       "location": "Table 1 - Row: Groceries & Essentials/ Barangan Keperluan & Runcit",
#       "doc1": {
#         "content": "| RM1,000                                     | Groceries & Essentials | \u2022 MCC: 5411 - All grocery stores including Giant, Cold Storage, Jaya Grocer, Mercato, etc. \u2022 MCC: 5912 - All drug stores and pharmacies including Guardian, Watsons, Caring Pharmacy, etc. \u2022 Selected convenience stores - MyNews and 7- Eleven. | ..."
#       },
#       "doc2": {
#         "content": "| RM1,000                                                 | Barangan Keperluan & Runcit | \u2022 MCC: 5411 - Semua kedai runcit termasuk Giant, Cold Storage, Jaya Grocer, Mercato, dan lain-lain. \u2022 MCC: 5912 - Semua kedai ubat dan farmasi termasuk Guardian, Watsons, Caring Pharmacy dan lain-lain \u2022 Kedai Serbaneka yang terpilih - MyNews and 7Eleven | ..."
#       },
#       "discrepancies": [
#         "1. 'Groceries & Essentials' in English is 'Barangan Keperluan & Runcit' in BM (word order reversed). Should be 'Barangan Runcit & Keperluan'.",
#         "2. 'All grocery stores' (English) is 'Semua kedai runcit' (BM). 'Grocery' (makanan) is different from 'kedai runcit' (which can also mean sundry shop); slight meaning shift.",
#         "3. 'Drug stores and pharmacies' becomes 'kedai ubat dan farmasi', which is accurate, but 'drug stores' (could be for over-the-counter) and 'farmasi' specifics are not mirrored.",
#         "4. 'Including Guardian, Watsons, Caring Pharmacy, etc.' becomes 'termasuk ... dan lain-lain.'; the 'etc.' is 'dan lain-lain', but BM omits comma before 'dan lain-lain'.",
#         "5. English 'Selected convenience stores - MyNews and 7- Eleven' translated as 'Kedai Serbaneka yang terpilih - MyNews and 7Eleven'; the dash '7- Eleven' has a space in English, not BM.",
#         "6. BM omits 'Selected', or at least doesn't clarify which convenience stores (as per the English phrase)."
#       ],
#       "explanation": "Word order, translation accuracy for 'Grocery', missing dashes, and 'Selected' not fully translated make for several discrepancies."
#     },
#     {
#       "location": "Table 1 - Petrol Row",
#       "doc1": {
#         "content": "| RM1,000                                     | Petrol                 | \u2022 MCC: 5542 | Enjoy 0.5% | Enjoy 10% | RM15 |"
#       },
#       "doc2": {
#         "content": "|                                                   | Petrol                      | \u2022 MCC: 5542 - Dispenser Bahan Bakar Automatik (layan diri) di semua stesen minyak | Nikmati 0.5% Pulangan Tunai | Nikmati 10% PulanganTunai | RM15 |"
#       },
#       "discrepancies": [
#         "1. English has only 'MCC: 5542'; BM expands this to 'MCC: 5542 - Dispenser Bahan Bakar Automatik (layan diri) di semua stesen minyak' \u2014 added explanatory detail in BM not appearing in English.",
#         "2. 'Enjoy 0.5%' and 'Enjoy 10%' in English are 'Nikmati 0.5% Pulangan Tunai' and 'Nikmati 10% PulanganTunai' in BM; the double capital 'Tunai' is run together in BM without a space.",
#         "3. English has 'Petrol' twice (as separate rows with different descriptions); BM merges the information."
#       ],
#       "explanation": "BM adds a detailed description of petrol transaction type not in English and has a run-on word in 'PulanganTunai'. English version is less specific about transaction type."
#     },
#     {
#       "location": "Table 1 - Online Spend row / Perbelanjaan Dalam Talian",
#       "doc1": {
#         "content": "|                                             | Online Spend                | \u2022 Lazada \u2022 Shopee \u2022 Grab \u2022 Foodpanda \u2022 Touch 'n Go \u2022 MYEG \u2022 Spotify \u2022 Netflix \u2022 Apple Music Note: Applicable to eWallet reload and food delivery transactions for the above listed merchant only | ... |"
#       },
#       "doc2": {
#         "content": "|                                                         | Perbelanjaan Dalam Talian   | \u2022 Lazada \u2022 Shopee \u2022 Grab \u2022 Foodpanda \u2022 Touch 'n Go \u2022 MYEG \u2022 Spotify | ... |"
#       },
#       "discrepancies": [
#         "1. English version includes 'Spotify \u2022 Netflix \u2022 Apple Music Note: Applicable to eWallet reload and food delivery transactions for the above listed merchant only' in this row; BM moves 'Netflix \u2022 Apple Music Nota: Termasuk tambah nilai e-wallet dan servis penghantaran makanan untuk peniaga yang disenaraikan di atas sahaja' to next row (broken table input).",
#         "2. In BM, 'Note' is translated as 'Nota', but placed at the start of the row and not at the end.",
#         "3. BM omits 'Applicable to eWallet reload and food delivery transactions for the above listed merchant only' from this row; appears in patchwork fashion in second row.",
#         "4. Spotify \u2022 Netflix \u2022 Apple Music do not all appear together or in same order in BM.",
#         "5. Structural/formatting misalignment between table rows."
#       ],
#       "explanation": "BM separates merchant names and descriptive notes awkwardly across table rows, rather than grouping as in English."
#     },
#     {
#       "location": "Table 1 - Others (including overseas)/Lain-lain",
#       "doc1": {
#         "content": "|                                             | Others (including overseas) | \u2022 Any Other Eligible MCC, Merchants and/or Transactions. | Enjoy 0.20% Cashback | Enjoy 0.20% Cashback | Unlimited |"
#       },
#       "doc2": {
#         "content": "|               | Lain-lain (Termasuk transaksi luar negara) | \u2022 Semua Kod Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak Yang Lain | Nikmati 0.20% Pulangan Tunai | Tiada Had |"
#       },
#       "discrepancies": [
#         "1. BM: 'Lain-lain (Termasuk transaksi luar negara)' adds direct translation; order of the phrase is slightly altered.",
#         "2. English: 'Any Other Eligible MCC, Merchants and/or Transactions.' BM: 'Semua Kod Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak Yang Lain,' a slightly different shape with 'Yang Lain' at the end \u2014 word order varies.",
#         "3. 'Enjoy 0.20% Cashback' x2 in English (Weekdays, Weekends); BM collapses to a single value.",
#         "4. 'Unlimited' in English is 'Tiada Had' in BM.",
#         "5. Cashback value column is omitted in BM."
#       ],
#       "explanation": "The main discrepancy is in the word ordering and presentation of the cashback value for weekdays/weekends (single in BM). Also, 'Unlimited' is translated idiomatically."
#     },
#     {
#       "location": "Table 1 - Below Minimum Spend row",
#       "doc1": {
#         "content": "| Below RM1,000                               | All                         | \u2022 All Eligible MCC, Merchants and/or Transactions. | Enjoy 0.20% Cashback | Enjoy 0.20% Cashback | RM2 |"
#       },
#       "doc2": {
#         "content": "| Bawah RM1,000 | Semua | \u2022 Semua Kod Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak Yang Lain | Nikmati 0.20% Pulangan Tunai | RM2 |"
#       },
#       "discrepancies": [
#         "1. English header is 'All', BM is 'Semua'.",
#         "2. The phrase 'Eligible MCC, Merchants and/or Transactions.' in English is 'Kod Kategori Peniaga (MCC), Peniaga dan/atau Transaksi Yang Layak Yang Lain' in BM; the term 'Eligible' is inserted and 'Yang Lain' placed at the end.",
#         "3. 'Enjoy 0.20% Cashback' x2 in English is only mentioned once in BM.",
#         "4. Table row structure is collapsed in BM (missing one column compared to English)."
#       ],
#       "explanation": "Word order, row structure, and phrase translations create inconsistencies here."
#     },
#     {
#       "location": "Section 1(c) Calculation of Cashback",
#       "doc1": {
#         "content": "- (c) The  entitlement  of  Cashback  is  calculated  based  on  posted  transaction  in  each  calendar month. Cardholders who do not meet the monthly minimum spend requirement of Ringgit Malaysia One Thousand (RM1,000) as stated under Clauses 1(a) (i) and (ii) above or in the event the posted amount is below Ringgit Malaysia One Thousand (RM1,000) in that particular calendar month, such Cardholders will not be entitled to the up to 1% (Weekdays) or 15% (Weekends)  Cashback  in  that  particular  month  as  stated  in  Table  1.  However,  such Cardholders will still be entitled to 0.20% Cashback for all their Eligible Retail Transactions (i.e. below Ringgit Malaysia One Thousand (RM1,000)) in that particular month provided that the accumulated Cashback amount is not less than Ringgit Malaysia One (RM1)."
#       },
#       "doc2": {
#         "content": "- (c)  Kelayakan menerima Pulangan Tunai dikira berdasarkan transaksi yang tercatat pada setiap bulan.  Pemegang Kad yang tidak memenuhi perbelanjaan minimum Ringgit Malaysia  Satu Ribu (RM1,000) sebulan seperti dinyatakan dalam Klausa 1(a)(i) dan (ii) atau sekiranya amaun transaksi yang tercatat itu adalah di bawah Ringgit Malaysia Satu Ribu (RM1,000) pada bulan kalendar  berkenaan,  Pemegang  Kad  tersebut  tidak  akan  layak  menerima  Pulangan  Tunai sehingga 1% (hari bekerja) atau 15% (hujung minggu) pada bulan berkenaan. Akan tetapi, Pemegang Kad tersebut tetap layak menerima Pulangan Tunai 0.2% bagi Transaksi Runcit Layak (i.e. bawah Ringgit Malaysia Seribu (RM1,000)) yang dibuat dalam bulan berkenaan dengan syarat jumlah pulangan tunai terkumpul tidak kurang daripada Ringgit Malaysia Satu (RM1)."
#       },
#       "discrepancies": [
#         "1. English: 'entitlement of Cashback is calculated based on posted transaction in each calendar month'; BM: 'dikira berdasarkan transaksi yang tercatat pada setiap bulan'\u2014'calendar' omitted.",
#         "2. English: 'such Cardholders will not be entitled to the up to 1% (Weekdays) or 15% (Weekends) Cashback...' BM: 'tidak akan layak menerima Pulangan Tunai sehingga 1% (hari bekerja) atau 15% (hujung minggu)...'; 'Pulangan Tunai' used generically, with percentages at different places.",
#         "3. BM omits explicit 'as stated in Table 1' found in English.",
#         "4. BM uses 'sebulan seperti dinyatakan dalam' which is similar to English 'monthly', but the repetition is not mirrored.",
#         "5. 'Eligible Retail Transactions (i.e. below Ringgit Malaysia One Thousand (RM1,000))' translated as 'Transaksi Runcit Layak (i.e. bawah Ringgit Malaysia Seribu (RM1,000))' missing explicit English 'for all their'.",
#         "6. Phrase 'in that particular month provided that the accumulated Cashback amount is not less than Ringgit Malaysia One (RM1)' is faithfully translated but omits 'that particular month' after 'provided that ...'."
#       ],
#       "explanation": "BM omits 'calendar', 'as stated in Table 1', and alters word order, with small translation and contextual word/phrase losses."
#     },
#     {
#       "location": "Table 2 - Transaction Type: Barangan Runcit & Keperluan",
#       "doc1": {
#         "content": "| Groceries & Essentials | RM150 | 13-Jul-24 | Saturday | 14-Jul-24 | Sunday |"
#       },
#       "doc2": {
#         "content": "| Barangan Runcit & Keperluan | RM150 | 13-Jul-24 | Sabtu | 14-Jul-24 | Ahad |"
#       },
#       "discrepancies": [
#         "1. English 'Groceries & Essentials' is reversed as 'Barangan Runcit & Keperluan' in BM (not matching 'Barangan Keperluan & Runcit' as in earlier BM table).",
#         "2. BM translation not standardized within document (earlier 'Barangan Keperluan & Runcit')."
#       ],
#       "explanation": "Internal BM inconsistency in translation for this spend category."
#     },
#     {
#       "location": "Table 2 - Transaction Type: Online Spend",
#       "doc1": {
#         "content": "| Online Spend | RM1,520 | 11-Jul-24 | Thursday | 12-Jul-24 | Friday |"
#       },
#       "doc2": {
#         "content": "| Perbelanjaan Dalam Talian | RM1,520 | 11-Jul-24 | Khamis | 12-Jul-24 | Jumaat |"
#       },
#       "discrepancies": [
#         "1. English 'Online Spend' is 'Perbelanjaan Dalam Talian' in BM; this translation is consistent, but not literal ('Perbelanjaan Atas Talian' is often used)."
#       ],
#       "explanation": "Slightly different but commonly accepted word-for-word translation."
#     },
#     {
#       "location": "Table 2 - Transaction Type: Dining",
#       "doc1": {
#         "content": "| Dining | RM 135 | 13-Jul-24 | Saturday | 14-Jul-24 | Sunday |"
#       },
#       "doc2": {
#         "content": "| Jamu Selera | RM135 | 13-Jul-24 | Sabtu | 14-Jul-24 | Ahad |"
#       },
#       "discrepancies": [
#         "1. The translation 'Dining' as 'Jamu Selera' is inconsistent with direct translation ('Makan' or 'Santapan').",
#         "2. Inconsistency with international standard translation."
#       ],
#       "explanation": "Repetitive issue of 'Jamu Selera' used for 'Dining', which is not standard."
#     },
#     {
#       "location": "Table 2 - Transaction Type: Others",
#       "doc1": {
#         "content": "| Others | RM20 | 23-Jul-24 | Tuesday | 24-Jul-24 | Wednesday |"
#       },
#       "doc2": {
#         "content": "| Lain | RM20 | 23-Jul-24 | Selasa | 24-Jul-24 | Rabu |"
#       },
#       "discrepancies": [
#         "1. 'Others' becomes 'Lain' in BM, but elsewhere 'Lain-lain' is used (BM internal inconsistency)."
#       ],
#       "explanation": "'Others' should be consistently translated as 'Lain-lain', not sometimes 'Lain'."
#     },
#     {
#       "location": "Table 2 - Transaction Type: Online Spend (Reversal)",
#       "doc1": {
#         "content": "| Online Spend (Reversal) | RM(20) | 20-Jul-24 | Saturday | 21-Jul-24 | Sunday |"
#       },
#       "doc2": {
#         "content": "| Perbelanjaan Dalam Talian (Pembalikan) | RM(20) | 20-Jul-24 | Sabtu | 21-Jul-24 | Ahad |"
#       },
#       "discrepancies": [
#         "1. 'Reversal' is translated as 'Pembalikan'; direct match.",
#         "2. English 'Online Spend (Reversal)' is 'Perbelanjaan Dalam Talian (Pembalikan)'; translation is correct, but not literal."
#       ],
#       "explanation": "No major loss of meaning, only literal translation deviation."
#     },
#     {
#       "location": "Q&A: Minimum Spend Calculation",
#       "doc1": {
#         "content": "Q: Does the Cardholder meet the minimum spend of RM1,000? A: Yes, the total posted transactions amount for July 2024 that will form part of the minimum spend... (which  consists  of  Ringgit  Malaysia  Four  Hundred  (RM400)  from  JomPay, Ringgit Malaysia One Hundred Fifty (RM150) from Groceries & Essentials, Ringgit Malaysia One Thousand Five Hundred (RM1,500) from Online Spend (after the reversal of RM20), Ringgit Malaysia One Hundred Thirty-Five (RM135) from Dining, Ringgit Malaysia One Hundred Fifty (RM150) from Petrol and Ringgit Malaysia Twenty (RM20) from Others)."
#       },
#       "doc2": {
#         "content": "Q: Adakah Pemegang Kad memenuhi perbelanjaan minimum RM1000? A: Ya, jumlah  transaksi tercatat pada Julai 2024 yang dikira sebagai perbelanjaan minimum Ringgit  Malaysia  Satu  Ribu  (RM1,000) adalah Ringgit Malaysia  Dua Ribu Tiga Ratus Lima Puluh  Lima  (RM2,355)  (yang  terdiri  daripada  Ringgit  Malaysia  Empat  Ratus  (RM400)  dari JomPAY, Ringgit Malaysia Seratus Lima Puluh (RM150) dari Barangan Runcit & Keperluan, Ringgit Malaysia Lapan Puluh (RM1,500) dari Perbelanjaan Dalam Talian (selepas tolak RM20 daripada Pembalikan), Ringgit Malaysia Seratus Tiga Puluh Lima (RM135) dari Jamu Selera, Ringgit Malaysia Seratus Lima Puluh (RM150) dari Petrol  dan Ringgit Malaysia Dua Puluh (RM20) dari Kategori Lain)"
#       },
#       "discrepancies": [
#         "1. BM: 'Ringgit Malaysia Lapan Puluh (RM1,500)' is an error; should be 'Ringgit Malaysia Seribu Lima Ratus (RM1,500)'.",
#         "2. English: 'from Groceries & Essentials'; BM: 'dari Barangan Runcit & Keperluan' (see previous note re: inconsistent translation order).",
#         "3. English: 'from Dining'; BM: 'dari Jamu Selera' (translation style issue, see above).",
#         "4. English: 'from Others'; BM: 'dari Kategori Lain' \u2014 category not always described as 'Kategori' in other tables.",
#         "5. BM: Internal numeric word/number mismatch ('Lapan Puluh (RM1,500)')."
#       ],
#       "explanation": "Main issue is spelling/amount error in BM ('Eighty' for RM1,500), inconsistent translation of categories, and some inconsistencies in description."
#     },
#     {
#       "location": "Q&A: Eligibility of JomPAY cashback",
#       "doc1": {
#         "content": "Q: How much Cashback did the Cardholder earn for the JomPAY transaction performed on 1 July 2024? A: Ringgit Malaysia Zero (RM0) as transaction(s) for JomPAY are not eligible for the Cashback. This is provided under Clause 3(a) below."
#       },
#       "doc2": {
#         "content": "Q: Berapa Pulangan Tunai yang diperoleh Pemegang Kad untuk transaksi JomPAY yang dilakukan pada 1 Julai 2024? A:  Ringgit  Malaysia  Sifar  (RM0)  kerana  transaksi  untuk  JomPAY  tidak  layak  mendapat Pulangan Tunai. Sila merujuk kepada Klausa 3(a) di bawah untuk maklumat lanjut."
#       },
#       "discrepancies": [
#         "1. English: 'This is provided under Clause 3(a) below.' BM: 'Sila merujuk kepada Klausa 3(a) di bawah untuk maklumat lanjut.' \u2014 English direct reference, BM adds 'untuk maklumat lanjut' as extra info (asymmetrical translation)."
#       ],
#       "explanation": "BM version adds extra phrase 'untuk maklumat lanjut' not present in English."
#     },
#     {
#       "location": "Q&A: Petrol cashback for 31 August transaction",
#       "doc1": {
#         "content": "Q: How much Cashback did the Cardholder earn in July for the transaction for Petrol on 31 August 2024? A: The Ringgit Malaysia One Hundred (RM100) Petrol transaction will not form part of the Cashback for  July  2024  (i.e.  Ringgit  Malaysia  Zero  (RM0)  Cashback)  as  it  is  only  posted  in  August  2024. However,  the  Ringgit  Malaysia  One  Hundred  (RM100)  Petrol  transaction  will  form  part  of  the Cashback for August 2024 (up to 15% Cashback if the Cardholder meets the Ringgit Malaysia One Thousand (RM1,000) minimum spend requirement in August or 0.20% Cashback otherwise (i.e. minimum spend amount below Ringgit Malaysia One Thousand (RM1000))."
#       },
#       "doc2": {
#         "content": "Q: Berapakah Pulangan Tunai yang diperoleh Pemegang Kad pada bulan Julai untuk transaksi Petrol pada 31 Ogos 2024? A:  Transaksi  Petrol  Ringgit  Malaysia  Seratus  (RM100)  tidak  akan  dianggap  sebahagian daripada pulangan tunai untuk Julai 2024 (iaitu pulangan tunai Ringgit Malaysia Sifar (RM0)) kerana transaksi tersebut hanya tercatat pada Ogos 2024. Walau bagaimanapun, transaksi Petrol Ringgit Malaysia Seratus (RM100) akan menjadi sebahagian daripada pulangan tunai untuk  Ogos  2024  (pulangan  tunai  15%  jika  Pemegang  kad  memenuhi  syarat  perbelanjaan minimum Ringgit Malaysia Satu Ribu (RM1,000) pada bulan Ogos; ataupun pulangan tunai 0.2%  sekiranya  perbelanjaan  minimum  tidak  tercapai.  i.e.  bawah  Ringgit  Malaysia  Seribu (RM1,000))."
#       },
#       "discrepancies": [
#         "1. English: 'as it is only posted in August 2024.' BM: 'kerana transaksi tersebut hanya tercatat pada Ogos 2024.' ('posted' vs 'tercatat').",
#         "2. English: 'up to 15% Cashback if the Cardholder meets... or 0.20% Cashback otherwise.' BM: 'pulangan tunai 15% jika Pemegang kad memenuhi syarat...; ataupun pulangan tunai 0.2% sekiranya...'. BM omits 'up to' (sehingga) for 'pulangan tunai 15%'.",
#         "3. English: 'minimum spend amount below Ringgit Malaysia One Thousand (RM1000)'. BM: 'i.e. bawah Ringgit Malaysia Seribu (RM1,000)).'",
#         "4. BM omits the word 'otherwise' (otherwise would be 'jika tidak')."
#       ],
#       "explanation": "BM misses some qualifiers and omits 'up to', changes 'posted' to 'tercatat', and reduces formality in end condition ('otherwise')."
#     },
#     {
#       "location": "Q&A: Total Cashback Earned in July",
#       "doc1": {
#         "content": "Q: What is the total amount of Cashback the Cardholder has earned for the month of  July 2024? A: Ringgit Malaysia Sixty-Five (RM65). Please refer to Table 3 below for the illustration of Cashback calculation for the month of July 2024."
#       },
#       "doc2": {
#         "content": "A: Ringgit Malaysia  Enam Puluh Lima (RM65). Sila rujuk Jadual 3 di bawah untuk ilustrasi pengiraan Pulangan Tunai bagi bulan Julai 2024."
#       },
#       "discrepancies": [
#         "1. English explicitly labels 'Q:'; BM omits explicit question.",
#         "2. English: 'illustration of Cashback calculation'; BM: 'ilustrasi pengiraan Pulangan Tunai' \u2014 'calculation of Cashback' translated as 'pengiraan Pulangan Tunai' ('of' translation is literal)."
#       ],
#       "explanation": "BM omits explicit 'Q' and literal structure varies slightly."
#     },
#     {
#       "location": "Table 3 - Dining Row",
#       "doc1": {
#         "content": "| Dining | 135 | 13-Jul (Weekend) | 15% | 20 | 20 |"
#       },
#       "doc2": {
#         "content": "| Jamu Selera | 200 | 13-Jul (Hujung Minggu) | 15% | 20 | 20 |"
#       },
#       "discrepancies": [
#         "1. BM value is '200', but in English it is '135' \u2014 inconsistent transaction value.",
#         "2. 'Weekend' is 'Hujung Minggu' in BM (correct translation).",
#         "3. 'Dining' is 'Jamu Selera' (already flagged issue of translation consistency)."
#       ],
#       "explanation": "Amount discrepancy: RM135 in English, RM200 in BM; repeated translation style issue."
#     },
#     {
#       "location": "Table 3 - Groceries & Essentials Row",
#       "doc1": {
#         "content": "| Groceries & Essentials | 150 | 13-Jul (Weekend) | 10% | 15 | 15 |"
#       },
#       "doc2": {
#         "content": "| Barangan Runcit & Keperluan | 450 | 13-Jul (Hujung Minggu) | 10% | 15 | 15 |"
#       },
#       "discrepancies": [
#         "1. Amount is '150' in English, '450' in BM.",
#         "2. Category name is reversed, as in previous flags."
#       ],
#       "explanation": "Discrepancy in transaction amount and translation order inconsistency."
#     },
#     {
#       "location": "Table 3 - Total Amount Row",
#       "doc1": {
#         "content": "| Total Amount of Cashback (RM) | 65 Note: The Cashback awarded will be rounded (up or down) to the settlement of the nearest Ringgit Malaysia | ..."
#       },
#       "doc2": {
#         "content": "Jumalah Pulangan 65 Tunai (RM) Nota: Pulangan tunai yang diberikan akan dibundarkan (atas atau bawah) kepada Ringgit Malaysia ('RM') yang terdekat."
#       },
#       "discrepancies": [
#         "1. BM has 'Jumalah', which is a spelling error; correct word is 'Jumlah'.",
#         "2. Word order: 'Pulangan 65 Tunai (RM)' is a nonstandard phrase arrangement.",
#         "3. English: 'Note: The Cashback awarded will be rounded (up or down) to the settlement of the nearest Ringgit Malaysia'; BM compresses the rounding note and omits 'settlement'."
#       ],
#       "explanation": "Spelling error and poor phrase construction in BM, 'settlement' word omitted."
#     },
#     {
#       "location": "Section 2 - Eligibility & Participation: Clause (a), (i)",
#       "doc1": {
#         "content": "- (i) the Cardholders of WISE Card account must be valid and in good standing, not overdue in payment and must not be closed or terminated by either the Cardholders or HLB;"
#       },
#       "doc2": {
#         "content": "- (i) Akaun Kad WISE Pemegang Kad mestilah sah, mempunyai rekod baik, bayaran tidak bertunggak dan tidak ditutup atau ditamatkan oleh sama ada oleh Pemegang Kad atau HLB;"
#       },
#       "discrepancies": [
#         "1. English 'the Cardholders of WISE Card account' is 'Akaun Kad WISE Pemegang Kad' (order reversed in BM).",
#         "2. BM says 'atan ditutup atau ditamatkan oleh sama ada oleh Pemegang Kad atau HLB'; extra repeated 'oleh'.",
#         "3. 'in good standing, not overdue in payment' is merged in BM as 'mempunyai rekod baik, bayaran tidak bertunggak', separating the qualities differently.",
#         "4. English 'must not be closed or terminated by either the Cardholders or HLB' is 'tidak ditutup atau ditamatkan oleh sama ada oleh Pemegang Kad atau HLB', which adds superfluous 'oleh' and may create ambiguity."
#       ],
#       "explanation": "Syntactic errors, repetition, and nonstandard translation of 'good standing' and account status."
#     },
#     {
#       "location": "Section 2(a)(ii)",
#       "doc1": {
#         "content": "- (ii) the Cardholders must not be in breach of any of these Terms and Conditions and/or the terms and conditions of the Agreement;"
#       },
#       "doc2": {
#         "content": "- (ii) Pemegang Kad mestilah tidak melanggar mana-mana Terma dan Syarat ini dan/atau terma dan syarat Perjanjian;"
#       },
#       "discrepancies": [
#         "1. English: 'must not be in breach of any of these Terms and Conditions'. BM: 'mestilah tidak melanggar mana-mana Terma dan Syarat ini' \u2014 translation is literal, but BM omits possessive 'of'."
#       ],
#       "explanation": "Translation is literal but omits possessive context."
#     },
#     {
#       "location": "Section 2(a)(iii)",
#       "doc1": {
#         "content": "- (iii) eligibility  will  be  revoked  in  respect  of  the  Cardholders  who  have  committed  or  are suspected of committing any fraudulent, unlawful or wrongful acts in relation to any of the facilities granted by HLB or have been declared bankrupt (pursuant to a petition by either banks or by any third party) or are subject to any bankruptcy proceedings at any time prior to, during or after the availability of the Programme."
#       },
#       "doc2": {
#         "content": "- (iii)  Kelayakan  akan  dibatalkan  bagi  Pemegang  Kad  yang  telah  melakukan  atau  disyaki melakukan sebarang penipuan atau kesalahan undang-undang berkaitan dengan manamana kemudahan yang diberi oleh HLB atau telah diisytiharkan muflis (menurut petisyen oleh  sama  ada  bank  atau  mana-mana  pihak  ketiga)  atau  bakal  dikenakan  prosiding kemuflisan pada bila-bila masa sebelum, semasa atau selepas Program selesai."
#       },
#       "discrepancies": [
#         "1. BM 'sebarang penipuan atau kesalahan undang-undang' omits 'wrongful acts' from English.",
#         "2. BM: 'bakal dikenakan prosiding kemuflisan pada bila-bila masa sebelum, semasa atau selepas Program selesai' translates as 'may be subjected to bankruptcy proceedings at any time before, during or after the Programme ends'; English says 'prior to, during or after the availability of the Programme', which is not literally 'after Programme ends'.",
#         "3. English: 'pursuant to a petition by either banks or by any third party'; BM: 'petisyen oleh  sama  ada  bank  atau  mana-mana  pihak  ketiga' (missing 'either ... or by', and extra spaces creating ambiguity)."
#       ],
#       "explanation": "BM omits mention of 'wrongful acts', changes the timeline (after Programme ends, instead of after availability), and has ambiguous/jumbled connective words."
#     },
#     {
#       "location": "Section 3(a) Definition of Eligible Retail Transaction",
#       "doc1": {
#         "content": "- (a) The term ' Eligible Retail Transaction ' shall refer to any retail purchase transaction made locally and overseas, including online transactions which are charged to the WISE Card (i.e. only applicable to the Principal WISE Cards) but EXCLUDE the following transactions (the list below is not exhaustive and HLB reserves the sole right to determine if a transaction fall within the definition of Eligible Retail Transactions):-"
#       },
#       "doc2": {
#         "content": "- (a) Terma ' Transaksi Runcit Layak ' bermaksud apa-apa transaksi belian runcit yang dibuat di dalam dan luar negara, termasuk transaksi dalam talian yang dicaj kepada Kad WISE (hanya tertakluk  pada  Kad  WISE  Utama ) tetapi TIDAK TERMASUK transaksi berikut (senarai di bawah  ini  tidak  lengkap  dan  HLB  berhak  menentukan  sama  ada  sesuatu  transaksi  itu terangkum dalam takrif Transaksi Runcit atau Pembelanjaan Runcit):"
#       },
#       "discrepancies": [
#         "1. English 'retail purchase transaction' is 'transaksi belian runcit' in BM; direct translation.",
#         "2. English: 'only applicable to the Principal WISE Cards'; BM: 'hanya tertakluk  pada  Kad  WISE  Utama', missing the plural 'Cards'.",
#         "3. English 'HLB reserves the sole right to determine if a transaction fall within the definition of Eligible Retail Transactions'; BM: 'HLB  berhak  menentukan  sama  ada  sesuatu  transaksi  itu terangkum dalam takrif Transaksi Runcit atau Pembelanjaan Runcit', which introduces 'Pembelanjaan Runcit' instead of just 'Transaksi Runcit Layak'; broadens scope.",
#         "4. English: (the list below is not exhaustive). BM: '(senarai di bawah  ini  tidak  lengkap)', correct but less formal."
#       ],
#       "explanation": "BM adds an extra possible meaning for Eligible Retail Transactions ('Pembelanjaan Runcit'), and only uses singular/plural for cards inconsistently."
#     },
#     {
#       "location": "Section 3(a)(vi)",
#       "doc1": {
#         "content": "- (vi) disputed transactions that are subsequently reversed from the account of the Principal Cardholder; and/or"
#       },
#       "doc2": {
#         "content": "- (vi)  Transaksi  yang  dipertikaikan  yang  kemudiannya  dibalikkan  daripada  akaun  Pemegang Kad; dan/atau"
#       },
#       "discrepancies": [
#         "1. English: 'from the account of the Principal Cardholder'; BM: 'daripada akaun Pemegang Kad'; omits clarification of 'Principal'."
#       ],
#       "explanation": "BM does not specify the main/Principal cardholder."
#     },
#     {
#       "location": "Section 3(a)(vii)",
#       "doc1": {
#         "content": "- (vii) QR Pay Transactions made via the HLB Connect App."
#       },
#       "doc2": {
#         "content": "- (vii) Transaksi QR Pay melalui HLB Connect App."
#       },
#       "discrepancies": [
#         "1. English: 'QR Pay Transactions made via the HLB Connect App' is in BM as 'Transaksi QR Pay melalui HLB Connect App'; missing 'made' ('dilakukan' or equivalent)."
#       ],
#       "explanation": "'Made' omitted from BM, which affects clarity."
#     },
#     {
#       "location": "Section 3(a), Paragraph After Exclusion List",
#       "doc1": {
#         "content": "Transactions that are not Eligible Retail Transactions will not be entitled to any Cashback and the amount spent  from  these  transactions  will  not  contribute  to  or  form  part  of  the  minimum  spend requirement of Ringgit Malaysia One Thousand (RM1,000) or any spend below RM1,000 for each calendar month."
#       },
#       "doc2": {
#         "content": "Transaksi  yang  bukan  merupakan  Transaksi  Runcit  Layak  tidak  akan  menerima  apa-apa Pulangan  Tunai  dan  amaun  yang  dibelanjakan  daripada  transaksi-transaksi  ini  tidak  akan menyumbang atau menjadi sebahagian perbelanjaan minimum  Ringgit Malaysia Satu Ribu (RM1,000) bagi setiap bulan kalendar."
#       },
#       "discrepancies": [
#         "1. BM omits explicit reference to 'or any spend below RM1,000 for each calendar month'.",
#         "2. English: 'not contribute to or form part of the minimum spend requirement of...' BM: 'tidak akan menyumbang atau menjadi sebahagian perbelanjaan minimum...', omits word 'requirement'."
#       ],
#       "explanation": "BM omits the clause 'or any spend below RM1,000 for each calendar month' and the word 'requirement', possibly changing the scope."
#     },
#     {
#       "location": "Section 3, 'All government, JomPAY and FPX transactions' Paragraph",
#       "doc1": {
#         "content": "For all government, JomPAY and/or FPX transactions, the amount spent from these transactions will contribute and form part of the minimum spend of Ringgit Malaysia One Thousand (RM1,000) for each calendar month. However, these transactions will not be entitled to any Cashback."
#       },
#       "doc2": {
#         "content": "Bagi  semua  transaksi  berkaitan  kerajaan,  JomPAY  dan/atau  transaksi  FPX,  amaun  yang dibelanjakan daripada transaksi ini akan menyumbang dan menjadi sebahagian perbelanjaan minimum Ringgit  Malaysia  Satu  Ribu  (RM1,000)    bagi  setiap  bulan  kalendar.  Akan  tetapi, transaksi-transaksi ini tidak akan layak menerima Pulangan Tunai."
#       },
#       "discrepancies": [
#         "1. English: 'the amount spent from these transactions will contribute and form part of the minimum spend ... for each calendar month'. BM: 'amaun  yang dibelanjakan ... akan menyumbang dan menjadi sebahagian perbelanjaan minimum ... bagi setiap bulan kalendar'; missing 'requirement' of minimum spend.",
#         "2. English: 'However, these transactions will not be entitled to any Cashback.' BM: 'tidak akan layak menerima Pulangan Tunai.' \u2014 literal translation, but omits 'entitled to'."
#       ],
#       "explanation": "Word choices and requirement scope differ."
#     },
#     {
#       "location": "Section 3(b), (c) - Definitions",
#       "doc1": {
#         "content": "- (b) The  term  ' HLB  Connect  App '  refers  to  the  Hong  Leong  Bank  Connect  Mobile  Banking Application.\n- (c) The term ' QR Pay Transaction ' means retail transactions made via the HLB Connect App using the HLB QR Pay feature."
#       },
#       "doc2": {
#         "content": "- (b)  Istilah ' HLB Connect App ' bermaksud Perbankan Mudah Alih Hong Leong Connect.\n- (c)  Istilah  ' Transaksi  QR  Pay' bermaksud  transaksi  runcit  dibuat  melalui  HLB  Connect  App mengunakan QR Pay."
#       },
#       "discrepancies": [
#         "1. English 'the Hong Leong Bank Connect Mobile Banking Application' is 'Perbankan Mudah Alih Hong Leong Connect' in BM; omits direct reference to 'Application'.",
#         "2. English 'the HLB QR Pay feature' is shortened to 'mengunakan QR Pay' in BM, omitting 'feature' and misspelling 'menggunakan' as 'mengunakan'."
#       ],
#       "explanation": "BM omits 'application' and has a spelling error in 'mengunakan'."
#     },
#     {
#       "location": "Section 3(d): Cashback Calculation",
#       "doc1": {
#         "content": "- (d) The Cashback will be calculated at the end of each calendar month based on the rate as shown in Table 1 above and is non-cumulative from the previous month. For the avoidance of doubt, Weekdays refer to Mondays to Fridays and Weekends refer to Saturdays and Sundays."
#       },
#       "doc2": {
#         "content": "- (d)  Pulangan Tunai akan dikira pada akhir setiap bulan kalendar berdasarkan kadar seperti tertera dalam Jadual dalam Jadual 1 di atas dan tidak kumulatif dari bulan sebelum. Bagi mengelakkan keraguan, Hari Minggu bermaksud Isnin hingga Jumaat dan Hujung Minggu bermaksud Sabtu dan Ahad."
#       },
#       "discrepancies": [
#         "1. BM: 'berdasarkan kadar seperti tertera dalam Jadual dalam Jadual 1 di atas' repeats 'Jadual' (should only be once, error).",
#         "2. English 'non-cumulative from the previous month' is 'tidak kumulatif dari bulan sebelum' in BM; BM omits 'from' in context.",
#         "3. BM misspells 'Jadual 1 di atas' as twice 'Jadual dalam Jadual'."
#       ],
#       "explanation": "Repetition ('Jadual dalam Jadual'), clarity of non-cumulative condition, and mapping of weekdays/weekends are main issues."
#     },
#     {
#       "location": "Section 3(e): Cashback Rounding and Crediting",
#       "doc1": {
#         "content": "- (e) The Cashback awarded will be rounded (up or down) to the settlement of the nearest Ringgit Malaysia (' RM '). The Cashback credits will be utilized towards any outstanding balances due on the WISE Card account. For the avoidance of doubt, any Cashback due to the Cardholders will  be  credited  to  the  WISE  Card  account  on  the  following  month  and  reflected  in  the Cardholders' statement. In the event the Cashback due to the Cardholders falls on or after the date of the Cardholders' statement, the Cashback will only be reflected in the Cardholders' statement in the following month."
#       },
#       "doc2": {
#         "content": "- (e)  Pulangan Tunai yang dianugerahkan akan dibundarkan (ke atas atau bawah) kepada kiraan Ringgit  Malaysia  (' RM ') yang  terhampir.  Kredit  Pulangan  Tunai  akan  digunakan  untuk menampung apa-apa baki belum lunas dalam akaun Kad WISE. Bagi mengelakkan keraguan, Pulangan Tunai yang kena dibayar kepada Pemegang Kad akan dikreditkan ke dalam akaun Kad  WISE  pada  bulan  berikut  dan  dipaparkan  dalam  Penyata  Pemegang  Kad.  Sekiranya Pulangan Tunai yang kena dibayar kepada Pemegang Kad matang pada atau selepas tarikh Penyata  Pemegang  Kad,  maka  Pulangan  Tunai  hanya  akan  dipaparkan  dalam  Penyata Pemegang Kad pada bulan berikutnya."
#       },
#       "discrepancies": [
#         "1. English: 'rounded (up or down) to the settlement of the nearest Ringgit Malaysia'; BM: 'dibundarkan (ke atas atau bawah) kepada kiraan Ringgit Malaysia ('RM') yang terhampir' \u2014 'settlement' is translated as 'kiraan', which means 'calculation/count', not settlement.",
#         "2. English 'Cashback credits will be utilized towards any outstanding balances...' BM: 'Kredit Pulangan Tunai akan digunakan untuk menampung apa-apa baki belum lunas' \u2014 omits 'utilized' and weakens the formality.",
#         "3. English makes three references to 'Cardholders' statement', BM four.",
#         "4. 'credited to the WISE Card account... and reflected in the Cardholders' statement' is translated as 'dikreditkan ke dalam akaun Kad  WISE  pada  bulan  berikut  dan  dipaparkan  dalam  Penyata  Pemegang  Kad', BM omits 'following month' in second occurrence.",
#         "5. English: 'the Cashback will only be reflected in the Cardholders' statement in the following month.' BM: 'maka  Pulangan  Tunai  hanya  akan  dipaparkan  dalam  Penyata Pemegang Kad pada bulan berikutnya.' BM omits 'the Cashback due to the Cardholders falls on or after the date'."
#       ],
#       "explanation": "BM uses 'kiraan' instead of 'settlement', omits some qualifiers, and alters phrase order."
#     },
#     {
#       "location": "Section 3(f): Foreign Transactions and Currency Conversion",
#       "doc1": {
#         "content": "- (f) The Cashback is awarded to the Cardholders based on the total posted amount of Eligible Retail  Transactions  in  RM  charged  to  the  WISE  Card.  All  overseas  transactions  and transactions performed in foreign currencies will be converted to RM at such rate of exchange as determined by HLB at its discretion."
#       },
#       "doc2": {
#         "content": "- (f) Pulangan Tunai diberi kepada Pemegang Kad berdasarkan jumlah amaun tercatat Transaksi Runcit  yang  Layak  dalam  RM  dicaj  kepada  Kad  WISE.  Semua  transaksi  luar  negara  dan transaksi yang dilakukan dalam mata wang asing akan ditukar kepada RM mengikut kadar pertukaran yang ditentukan oleh HLB atas budi bicaranya yang mutlak."
#       },
#       "discrepancies": [
#         "1. English: 'at its discretion' is 'atas budi bicaranya yang mutlak' in BM \u2014 BM adds 'mutlak' (absolute).",
#         "2. English: 'total posted amount ... charged to the WISE Card'; BM reverses order.",
#         "3. Both versions are conceptually similar, only minor qualifying word addition in BM."
#       ],
#       "explanation": "Small difference: BM adds 'yang mutlak' (absolute discretion) not in English."
#     },
#     {
#       "location": "Section 3(h): Cashback Rate Revision",
#       "doc1": {
#         "content": "- (h) HLB reserves its rights from time to time, with prior notice, to revise the rate of the Cashback awarded at its discretion."
#       },
#       "doc2": {
#         "content": "- (h)  HLB berhak dari semasa ke semasa, setelah notis awal diberi, meminda kadar Pulangan Tunai menurut budi bicaranya yang mutlak."
#       },
#       "discrepancies": [
#         "1. English: 'with prior notice,' BM: 'setelah notis awal diberi,' (different emphasis).",
#         "2. BM adds 'yang mutlak' (absolute discretion) again; English says only 'at its discretion'."
#       ],
#       "explanation": "Minor wording and qualifying difference."
#     },
#     {
#       "location": "Section 3(i): Merchant Category Assignment",
#       "doc1": {
#         "content": "- (i) The  assignment  of  the  Merchant  Category  and  the  Merchant  Category  Code  for  each merchant  is  subject  to  classification  by  the  respective  acquiring  banks  and  it  is  the responsibility of the particular acquiring bank to assign the correct Merchant Category and Merchant Category Code. HLB shall  not be held responsible for  any  incorrect  or  different assignment of the Merchant Category and Merchant Category Code that may result in (i) a transaction not being categorised as an Eligible Retail Transaction and/or (ii) non-posting of the Cashback for Eligible Retail Transaction at the eligible merchants. The Cardholder shall not  be  entitled  to  claim  for  any  compensation  against  HLB  for  such  non-posting  of  the Cashback due to incorrect or different assignment of the Merchant Category by the respective merchant's acquiring bank."
#       },
#       "doc2": {
#         "content": "- (i) Penetapan Kategori Peniaga dan Kod Kategori Peniaga bagi setiap peniaga adalah tertakluk kepada  pengelasan  oleh  bank-bank  pemperoleh  masing-masing  dan  bank  pemeroleh berkenaan bertanggungjawab menentukan Kategori Peniaga dan Kod Kategori Peniaga yang betul.  HLB  tidak  akan  bertanggungjawab  terhadap  penetapan  Kategori  Peniaga  dan  Kod Kategori  Peniaga  yang  tidak  betul  atau  berbeza  sehingga  menyebabkan  (i)  transaksi  tidak dikategorikan  sebagai  Transaksi  Runcit  Layak  dan/atau  (ii)  Pulangan  Tunai  bagi  Transaksi Runcit  Layak  tidak    tercatat  pada  peniaga  yang  layak.  Pemegang  Kad  tidak  akan  berhak menuntut  apa-apa  pampasan  terhadap  HLB  atas  Pulangan  Tunai  tidak  tercatat  lantaran penetapan  Kategori  Peniaga  yang  tidak  betul  atau  berbeza  oleh  bank  pemeroleh  peniaga masing-masing."
#       },
#       "discrepancies": [
#         "1. English: 'non-posting of the Cashback for Eligible Retail Transaction at the eligible merchants.' BM omits 'at the eligible merchants' ('pada peniaga yang layak' appears, but not in same clause).",
#         "2. 'The Cardholder shall not be entitled to claim for any compensation against HLB' is translated as 'Pemegang Kad tidak akan berhak menuntut  apa-apa  pampasan terhadap HLB', omitting sense of 'shall not be entitled to claim for any compensation'.",
#         "3. BM adds 'lantaran' (due to/because of), not in English.",
#         "4. English: 'assignment of the Merchant Category and the Merchant Category Code that may result in' is compressed in BM.",
#         "5. BM omits 'by the respective merchant's acquiring bank' in last instance."
#       ],
#       "explanation": "Numerous condensing of English material, compressed phrases, and omissions."
#     },
#     {
#       "location": "Section 3(j): T&Cs Revision Period",
#       "doc1": {
#         "content": "- (j) HLB may from time to time, at its discretion, by giving prior notice of at least twenty-one (21) calendar days to the Cardholders, change, revise, or vary any of the T&Cs herein."
#       },
#       "doc2": {
#         "content": "- (j) HLB boleh dari semasa ke semasa, atas budi bicaranya yang mutlak, setelah memberi notis awal  sekurang-kurangnya  dua  puluh  satu  (21)  hari  kalendar  kepada  Pemegang  Kad, mengubah, meminda, atau menukar mana-mana T&S ini."
#       },
#       "discrepancies": [
#         "1. BM: Adds 'yang mutlak' (absolute discretion) not in English.",
#         "2. Sequence of 'at its discretion, by giving prior notice ...' switched in BM.",
#         "3. English: 'change, revise, or vary'; BM: 'mengubah, meminda, atau menukar' (literal translation but not standardized term for 'vary')."
#       ],
#       "explanation": "BM adds 'absolute discretion' qualifier, and rearranges clause order."
#     },
#     {
#       "location": "Section 3(k): Reversal of Cashback for Reversed Transactions",
#       "doc1": {
#         "content": "- (k) The Cardholders' minimum spend amount will determine the Cashback entitlement rates of the Cardholders based on Table 1 above. If Cashback is given in respect of any Eligible Retail Transaction  which  is  subsequently  reversed,  the  reversal  will  result  in  the  corresponding Cashback being reversed regardless of the original transaction posting date. Any reversed transaction and/or cancelled transaction will be excluded from receiving the Cashback."
#       },
#       "doc2": {
#         "content": "- (k)  Amaun perbelanjaan minimum Pemegang Kad akan menentukan kadar kelayakan Pulangan Tunai Pemegang Kad berdasarkan Jadual 1 di atas. Jika Pulangan Tunai diberi bagi manamana  Transaksi  Runcit  Layak  yang  kemudiannya  dibalikkan,  maka  pembalikan  itu  akan menyebabkan  Pulangan  Tunai  bersamaan  turut  dibalikkan  tanpa  mengira  tarikh  tercatat transaksi  asal.  Sebarang  transaksi  dibalikkan  dan/atau  transaksi  yang  dibatalkan  akan dikecualikan daripada menerima Pulangan Tunai."
#       },
#       "discrepancies": [
#         "1. English: 'regardless of the original transaction posting date' BM: 'tanpa mengira tarikh tercatat transaksi asal'. BM omits the word 'original' in key phrase.",
#         "2. English: 'Any reversed transaction and/or cancelled transaction will be excluded from receiving the Cashback.' BM: 'akan dikecualikan daripada menerima Pulangan Tunai.' (literal, no content loss)."
#       ],
#       "explanation": "BM misses 'original' before 'posting date'."
#     },
#     {
#       "location": "Section 4 - Annual Fee",
#       "doc1": {
#         "content": "Annual Fee will be levied as follows:\n\n| Principal Cardholder     | RM98   |\n|--------------------------|--------|\n| Supplementary Cardholder | RM48   |\n\nThere is no annual fee waiver for WISE Card."
#       },
#       "doc2": {
#         "content": "Fi Tahunan akan dikenakan seperti berikut:\n\n| Pemegang Kad Utama    | RM98   |\n|-----------------------|--------|\n| Pemegang Kad Tambahan | RM48   |\n\nFi tahunan tidak akan dikecualikan untuk Kad WISE."
#       },
#       "discrepancies": [
#         "1. 'Annual fee waiver' in English is 'tidak akan dikecualikan' in BM, but not literally 'waiver'.",
#         "2. 'Supplementary Cardholder' is translated as 'Pemegang Kad Tambahan', which is standard, but may invite confusion for those used to 'tambahan' meaning 'additional'."
#       ],
#       "explanation": "BM omits explicit reference to 'waiver' and changes formality."
#     },
#     {
#       "location": "Section 5 - Product Features Variation",
#       "doc1": {
#         "content": "HLB reserves the right to amend, vary or alter any of the product features for the WISE Card or withdraw the WISE Card at any time with prior notice to the Cardholders and such amendments shall be effective on such date that HLB may elect to adopt. Subsequently, HLB may at its discretion mail directly to the Cardholders or notify in the mass media or post a notice at HLB's banking hall or at HLB's website at www.hlb.com.my or any method which HLB deems practical for such additions, modifications or amendments of the product features."
#       },
#       "doc2": {
#         "content": "HLB  berhak  meminda,  mengubah  atau  menukar  mana-mana  ciri  produk  bagi  Kad  WISE  atau menarik balik Kad WISE pada bila-bila masa setelah notis awal diberi kepada Pemegang Kad. Pertukaran  dan  pemindaan  tersebut  akan  berkuat  kuasa  pada  tarikh  yang  dipilih  oleh  HLB. Berikutan  itu,  HLB  boleh  atas  budi  bicaranya  menghantar  terus  kepada  Pemegang  Kad  atau memaklumkan melalui media massa atau menghebahkan notis dalam dewan perbankan HLB Bank atau laman web HLB di www.hlb.com.my atau apa-apa cara yang HLB anggap sesuai tentang penambahan, pengubahsuaian atau pemindaan ciri-ciri produk itu."
#       },
#       "discrepancies": [
#         "1. 'amend, vary, or alter' is translated as 'meminda, mengubah, atau menukar' \u2014 not literal, may create ambiguity.",
#         "2. English 'such amendments shall be effective on such date that HLB may elect to adopt' is 'Pertukaran dan pemindaan tersebut akan berkuat kuasa pada tarikh yang dipilih oleh HLB' \u2014 omitting 'may elect to adopt', which is more conditional.",
#         "3. English: 'at its discretion mail directly to the Cardholders or notify in the mass media or post a notice at HLB's banking hall or at HLB's website ...' BM: 'menghantar  terus  kepada  Pemegang  Kad  atau memaklumkan melalui media massa atau menghebahkan notis dalam dewan perbankan HLB Bank atau laman web HLB ...' BM omits 'at its discretion' for mailing directly.",
#         "4. 'At any time with prior notice' in English is 'pada bila-bila masa setelah notis awal diberi...' in BM \u2014 restructured and qualifer omitted.",
#         "5. English 'any method which HLB deems practical ...' BM: 'apa-apa cara yang HLB anggap sesuai ...', which omits 'practical' specificity."
#       ],
#       "explanation": "'May elect to adopt' becomes 'chosen by HLB', qualifiers and some formal language omitted, and terms like 'practical' become 'suitable'."
#     },
#     {
#       "location": "Section 5 - Additional Clause (BM only)",
#       "doc1": {
#         "content": "If you have any enquiries regarding these T&Cs, you may seek clarification from our staff who attended to you. Alternatively, please email us at hlonline@hlbb.hongleong.com.my."
#       },
#       "doc2": {
#         "content": "Jika anda mempunyai sebarang pertanyaan mengenai T&S ini, anda boleh mendapatkan penjelasan daripada kakitangan kami yang sedang melayan anda. Sebagai alternatif, sila e-mel kepada kami di hlonline@hlbb.hongleong.com.my."
#       },
#       "discrepancies": [
#         "1. English: 'staff who attended to you' is 'kakitangan kami yang sedang melayan anda' in BM, translating 'attending staff' as 'currently serving you'.",
#         "2. 'Alternatively, please email us at ...' is 'Sebagai alternatif, sila e-mel kepada kami di ...' \u2014 'please' is stated in English only, not BM."
#       ],
#       "explanation": "Translation for 'attended to you' differs, changing temporal context."
#     },
#     {
#       "location": "Section 5 and 6 - Reward Points Clause (BM Only)",
#       "doc1": {
#         "content": "[No equivalent clause for reward points.]"
#       },
#       "doc2": {
#         "content": "## 5. Mata Ganjaran\n\nMata ganjaran tidak diberi bagi Kad WISE."
#       },
#       "discrepancies": [
#         "1. BM includes a clause 'Mata ganjaran tidak diberi bagi Kad WISE' (No reward points are given for WISE Card) which is missing in English."
#       ],
#       "explanation": "BM document contains a product feature clause about reward points that does not exist in the English version."
#     }
#   ]
# }

# %%
# from dotenv import load_dotenv
# from langchain_openai import ChatOpenAI
# from langchain_core.output_parsers import StrOutputParser
# load_dotenv()

# reasoning = {
#     # "effort": "high",  # 'low', 'medium', or 'high'
# }
# model2 = ChatOpenAI(model="gpt-4.1", use_responses_api=True, model_kwargs={"reasoning": reasoning})
# chain2 = prompt | model2 | StrOutputParser()
# result2 = chain2.invoke({"doc1": doc1_content, "doc2": doc2_content})

# %%
# import json
# import re

# json_str = result2
# match = re.search(r"```json\s*(\{.*\})\s*```", result2, re.DOTALL)
# if match:
#     json_str = match.group(1)
# try:
#     result_dict = json.loads(json_str)  # Attempt to parse the JSON
#     if result_dict.get("flags"):  # Check if "flags" key exists and is not empty
#         print(json.dumps(result_dict, indent=2))
#     else:
#         print("No flags found in the result.")
# except json.JSONDecodeError as e:
#     print(f"Error decoding JSON: {e}")
